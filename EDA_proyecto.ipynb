# %%
# Importación de librerías
import pandas as pd
import numpy as np
# Configuración para visualizar todas las columnas del DataFrame
pd.set_option('display.max_columns', None)

# Gestión de warnings
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv("files/calidad_vida.csv")

# %%
df.head()
# Out:
#                  estudio FechaInicio HoraInicio   FechaFin   HoraFin Duración  \
# 0  10409_CAL_VIDA_25Dist   19-sep-25   13:28:13  19-sep-25  13:43:06  0:14:53
# 1  10409_CAL_VIDA_25Dist   19-sep-25   13:29:37  19-sep-25  13:44:01  0:14:24
# 2  10409_CAL_VIDA_25Dist   19-sep-25   13:29:50  19-sep-25  13:44:29  0:14:39
# 3  10409_CAL_VIDA_25Dist   19-sep-25   13:29:52  19-sep-25  13:44:18  0:14:26
# 4  10409_CAL_VIDA_25Dist   19-sep-25   13:30:16  19-sep-25  13:45:40  0:15:24
#
#    NúmeroEntrevista  DISTRITO  (P0B*R1AE) - Sexo (anotar)  \
# 0           1449659         2                           1
# 1           1449660         4                           1
# 2           1449661         8                           1
# 3           1449662         5                           1
# 4           1449663        20                           1
#
#    (P0D*R1AS) - ¿Me puede decir su edad?  \
# 0                                      1
# 1                                      4
# 2                                      3
# 3                                      3
# 4                                      4
#
#    P0F*R1AS) - Actualmente, ¿está viviendo en...?  (P1*M1AS) - a - En Madrid  \
# 0                                               1                          9
# 1                                               1                         10
# 2                                               4                          9
# 3                                               4                          7
# 4                                               3                         10
#
#    (P1*M1AS) - b - En su distrito  (P1*M1AS) - c - En su barrio  \
# 0                               9                             9
# 1                               9                            10
# 2                               8                             9
# 3                               7                             8
# 4                               7                            10
#
#    (P2*M10S) - a - En Madrid  (P2*M10S) - b - En su distrito  \
# 0                          8                               8
# 1                          9                               9
# 2                          8                               7
# 3                          7                               7
# 4                          9                               7
#
#    (P2*M10S) - c - En su barrio  (P3*M10S) - a - En Madrid  \
# 0                             9                          8
# 1                             9                         10
# 2                             8                          7
# 3                             7                          6
# 4                             9                         10
#
#    (P3*M10S) - b - En su distrito  (P3*M10S) - c - En su barrio  \
# 0                               9                            10
# 1                              10                            10
# 2                               8                             9
# 3                               9                             8
# 4                               9                            10
#
#    (P4*M10S) - a - Cuidado y conservación de la ciudad  \
# 0                                                  8
# 1                                                  8
# 2                                                  5
# 3                                                  7
# 4                                                  8
#
#    (P4*M10S) - b - Movilidad y transporte público  \
# 0                                              10
# 1                                              10
# 2                                               7
# 3                                               8
# 4                                               9
#
#    (P4*M10S) - c - Calidad medioambiental  \
# 0                                       9
# 1                                       7
# 2                                       5
# 3                                       6
# 4                                       6
#
#    (P4*M10S) - d - Facilidad para encontrar un trabajo  \
# 0                                                  8
# 1                                                  9
# 2                                                  5
# 3                                                  7
# 4                                                  7
#
#    (P4*M10S) - e - Facilidad para emprender un negocio  \
# 0                                                 99
# 1                                                  9
# 2                                                  5
# 3                                                  6
# 4                                                  7
#
#    (P4*M10S) - f - Imagen internacional de Madrid  \
# 0                                               9
# 1                                              10
# 2                                               8
# 3                                               8
# 4                                               9
#
#    (P4*M10S) - g - Coste de la vida  (P4*M10S) - h - Integración social  \
# 0                                 5                                   8
# 1                                 7                                   8
# 2                                 5                                   7
# 3                                 9                                   7
# 4                                 5                                  99
#
#    (P4*M10S) - i - Salud y servicios sanitarios  \
# 0                                             8
# 1                                             8
# 2                                             5
# 3                                             7
# 4                                             9
#
#    (P4*M10S) - j - Educación y centros educativos  \
# 0                                               8
# 1                                               8
# 2                                               7
# 3                                               7
# 4                                              99
#
#    (P4*M10S) - k - Facilidad para encontrar una vivienda en el marco de sus posibilidades  \
# 0                                                  4
# 1                                                  7
# 2                                                  2
# 3                                                  7
# 4                                                  4
#
#    (P4*M10S) - l - Facilidad para hacer deporte  \
# 0                                            10
# 1                                             9
# 2                                             7
# 3                                             7
# 4                                            10
#
#    (P4*M10S) - m - Oferta cultural, ocio y diversión  \
# 0                                                 10
# 1                                                 10
# 2                                                  8
# 3                                                  7
# 4                                                 10
#
#    (P4*M10S) - n - Convivencia vecinal  (P4*M10S) - o - Seguridad  \
# 0                                    7                          9
# 1                                    7                          8
# 2                                    7                          7
# 3                                    7                          7
# 4                                    8                          7
#
#    (P5A*R1AE) - ¿Cuáles son, a su juicio y por orden de prioridad, los tres problemas principales que existen actualmente en la ciudad de Madrid? (anotar 1ª problema)  \
# 0                                                4.0
# 1                                                NaN
# 2                                                4.0
# 3                                                NaN
# 4                                                NaN
#
#    (P5B*R1AE) - Anotar 2ª problema  (P5C*R1AE) - Anotar 3ª problema P4_Total  \
# 0                             97.0                             99.0  4;97;99
# 1                              NaN                              NaN      NaN
# 2                              8.0                             10.0   4;8;10
# 3                              NaN                              NaN      NaN
# 4                              NaN                              NaN      NaN
#
#    (P6*M10S) - a - Desigualdad de oportunidades entre hombres y mujeres  \
# 0                                                7.0
# 1                                                NaN
# 2                                                7.0
# 3                                                NaN
# 4                                                NaN
#
#    (P6*M10S) - b - Desigualdad de oportunidades entre la población extranjera y autóctona  \
# 0                                                7.0
# 1                                                NaN
# 2                                                7.0
# 3                                                NaN
# 4                                                NaN
#
#    (P7*M10S) - a - Las personas mayores  (P7*M10S) - b - La infancia  \
# 0                                   8.0                          8.0
# 1                                   NaN                          NaN
# 2                                   5.0                          5.0
# 3                                   NaN                          NaN
# 4                                   NaN                          NaN
#
#    (P7*M10S) - c - Las personas con discapacidad  \
# 0                                            7.0
# 1                                            NaN
# 2                                            5.0
# 3                                            NaN
# 4                                            NaN
#
#    (P7*M10S) - d - Las personas lgtbiq+  (P7*M10S) - e - Los migrantes  \
# 0                                   8.0                            7.0
# 1                                   NaN                            NaN
# 2                                   7.0                            5.0
# 3                                   NaN                            NaN
# 4                                   NaN                            NaN
#
#    (7*M10S) - f - La adolescencia  \
# 0                             8.0
# 1                             NaN
# 2                             8.0
# 3                             NaN
# 4                             NaN
#
#    (P8*M10S) - a - La recogida de basuras y contenedores  \
# 0                                                8.0
# 1                                                NaN
# 2                                                6.0
# 3                                                NaN
# 4                                                NaN
#
#    (P8*M10S) - b - La gestión y tratamiento de residuos (reciclaje, compostaje, etc.)  \
# 0                                                8.0
# 1                                                NaN
# 2                                                5.0
# 3                                                NaN
# 4                                                NaN
#
#    (P8*M10S) - c - El control de la contaminación atmosférica  \
# 0                                                7.0
# 1                                                NaN
# 2                                                5.0
# 3                                                NaN
# 4                                                NaN
#
#    (P8*M10S) - d - El control del ruido  \
# 0                                   8.0
# 1                                   NaN
# 2                                   5.0
# 3                                   NaN
# 4                                   NaN
#
#    (P8*M10S) - e - La limpieza de las calles  \
# 0                                        8.0
# 1                                        NaN
# 2                                        5.0
# 3                                        NaN
# 4                                        NaN
#
#    (P8*M10S) - f - El alumbrado público  \
# 0                                   8.0
# 1                                   NaN
# 2                                   5.0
# 3                                   NaN
# 4                                   NaN
#
#    (P8*M10S) - g - Las infraestructuras de la ciudad para la circulación de vehículos (calles, túneles, etc.…)  \
# 0                                                9.0
# 1                                                NaN
# 2                                                6.0
# 3                                                NaN
# 4                                                NaN
#
#    (P8*M10S) - h - La pavimentación y conservación de las aceras  \
# 0                                                7.0
# 1                                                NaN
# 2                                                2.0
# 3                                                NaN
# 4                                                NaN
#
#    (P8*M10S) - i - El asfaltado y conservación de las calzadas  \
# 0                                                8.0
# 1                                                NaN
# 2                                                2.0
# 3                                                NaN
# 4                                                NaN
#
#    (P8*M10S) - j - La peatonalización de calles  \
# 0                                           8.0
# 1                                           NaN
# 2                                           5.0
# 3                                           NaN
# 4                                           NaN
#
#    (P8*M10S) - k - La eliminación de barreras arquitectónicas (rebaje de bordillos, semáforos acústicos, etc.)  \
# 0                                                7.0
# 1                                                NaN
# 2                                                5.0
# 3                                                NaN
# 4                                                NaN
#
#    (P8*M10S) - l - La movilidad sostenible  \
# 0                                      8.0
# 1                                      NaN
# 2                                      5.0
# 3                                      NaN
# 4                                      NaN
#
#    (P8*M10S) - v - La mejora de la calidad del aire  \
# 0                                               7.0
# 1                                               NaN
# 2                                               5.0
# 3                                               NaN
# 4                                               NaN
#
#    (P8*M10S) - m - La conservación y rehabilitación de los edificios  \
# 0                                                7.0
# 1                                                NaN
# 2                                                5.0
# 3                                                NaN
# 4                                                NaN
#
#    (P8*M10S) - n - La protección de monumentos y del patrimonio histórico-artístico  \
# 0                                                8.0
# 1                                                NaN
# 2                                                7.0
# 3                                                NaN
# 4                                                NaN
#
#    (P8*M10S) - o - La información y promoción turística  \
# 0                                                8.0
# 1                                                NaN
# 2                                                8.0
# 3                                                NaN
# 4                                                NaN
#
#    (P8*M10S) - p - La organización de fiestas y eventos populares (cabalgata, fiestas de san isidro, fiestas de los distritos...)  \
# 0                                                7.0
# 1                                                NaN
# 2                                                7.0
# 3                                                NaN
# 4                                                NaN
#
#    (P8*M10S) - q - El control de la salud pública (plagas, alimentos, aguas...)  \
# 0                                                7.0
# 1                                                NaN
# 2                                                5.0
# 3                                                NaN
# 4                                                NaN
#
#    (P8*M10S) - r - Las ayudas e incentivos a pymes y autónomos  \
# 0                                                9.0
# 1                                                NaN
# 2                                                6.0
# 3                                                NaN
# 4                                                NaN
#
#    (P8*M10S) - s - La información al consumidor  \
# 0                                           9.0
# 1                                           NaN
# 2                                           8.0
# 3                                           NaN
# 4                                           NaN
#
#    (P8*M10S) - t - La promoción pública de viviendas  \
# 0                                                5.0
# 1                                                NaN
# 2                                                2.0
# 3                                                NaN
# 4                                                NaN
#
#    (P8*M10S) - w - La actuación frente a la ocupación ilegal  \
# 0                                                8.0
# 1                                                NaN
# 2                                                2.0
# 3                                                NaN
# 4                                                NaN
#
#    (P8*M10S) - u - Los beneficios fiscales promovidos por el ayuntamiento (bajada de impuestos, bonificaciones...)  \
# 0                                                8.0
# 1                                                NaN
# 2                                                8.0
# 3                                                NaN
# 4                                                NaN
#
#    (P8*M10S) - x - El plan de fomento de la natalidad y la conciliación (el cheque bebé)  \
# 0                                                6.0
# 1                                                NaN
# 2                                                5.0
# 3                                                NaN
# 4                                                NaN
#
#    (P9*M10S) - a - La atención a la ciudadanía  \
# 0                                          NaN
# 1                                          8.0
# 2                                          NaN
# 3                                          7.0
# 4                                          8.0
#
#    (P9*M10S) - c - El servicio de autobuses de la Emt  \
# 0                                                NaN
# 1                                               10.0
# 2                                                NaN
# 3                                                7.0
# 4                                                9.0
#
#    (P9*M10S) - d - Los taxis  \
# 0                        NaN
# 1                        8.0
# 2                        NaN
# 3                        6.0
# 4                        6.0
#
#    (P9*M10S) - e - El ser (servicio de estacionamiento regulado)  \
# 0                                                NaN
# 1                                                9.0
# 2                                                NaN
# 3                                                8.0
# 4                                                6.0
#
#    (P9*M10S) - f - Los agentes de movilidad  \
# 0                                       NaN
# 1                                       8.0
# 2                                       NaN
# 3                                       7.0
# 4                                       6.0
#
#    (P9*M10S) - g - La policía municipal  (P9*M10S) - h - Los bomberos  \
# 0                                   NaN                           NaN
# 1                                   8.0                          10.0
# 2                                   NaN                           NaN
# 3                                   8.0                           7.0
# 4                                   8.0                          10.0
#
#    (P9*M10S) - i - Samur – protección civil  \
# 0                                       NaN
# 1                                       9.0
# 2                                       NaN
# 3                                       6.0
# 4                                      10.0
#
#    (P9*M10S) - j - La beca infantil para la escolarización 0-3 años  \
# 0                                                NaN
# 1                                                9.0
# 2                                                NaN
# 3                                                8.0
# 4                                               99.0
#
#    (P9*M10S) - k - Los servicios sociales municipales (mayores, personas con discapacidad, inmigrantes, familias, …)  \
# 0                                                NaN
# 1                                                8.0
# 2                                                NaN
# 3                                                8.0
# 4                                                8.0
#
#    (P9*M10S) - l - Las vías ciclistas  \
# 0                                 NaN
# 1                                 7.0
# 2                                 NaN
# 3                                 7.0
# 4                                 5.0
#
#    (P9*M10S) - m - Los aparcamientos municipales  \
# 0                                            NaN
# 1                                            9.0
# 2                                            NaN
# 3                                            8.0
# 4                                            8.0
#
#    (P9*M10S) - n - Los puntos limpios de recogida y reciclaje de residuos  \
# 0                                                NaN
# 1                                                9.0
# 2                                                NaN
# 3                                                5.0
# 4                                                9.0
#
#    (P9*M10S) - o - Los espacios verdes (parques y jardines)  \
# 0                                                NaN
# 1                                                8.0
# 2                                                NaN
# 3                                                7.0
# 4                                                9.0
#
#    (P9*M10S) - p - Los parques infantiles  \
# 0                                     NaN
# 1                                     8.0
# 2                                     NaN
# 3                                     7.0
# 4                                     8.0
#
#    (P9*M10S) - q - Los mercados municipales  \
# 0                                       NaN
# 1                                       8.0
# 2                                       NaN
# 3                                       8.0
# 4                                       9.0
#
#    (P9*M10S) - r - Las instalaciones deportivas municipales  \
# 0                                                NaN
# 1                                                8.0
# 2                                                NaN
# 3                                                6.0
# 4                                               10.0
#
#    (P9*M10S) - s - Los centros culturales municipales  \
# 0                                                NaN
# 1                                                8.0
# 2                                                NaN
# 3                                                7.0
# 4                                               10.0
#
#    (P9*M10S) - t - Las bibliotecas municipales  \
# 0                                          NaN
# 1                                          8.0
# 2                                          NaN
# 3                                          8.0
# 4                                         10.0
#
#    (P9*M10S) - u - Los teatros municipales (Español, Matadero, Fernán Gómez…)  \
# 0                                                NaN
# 1                                                8.0
# 2                                                NaN
# 3                                                9.0
# 4                                                9.0
#
#    (P9*M10S) - v - El Samur social  (P9*M10S) - w - Bicimad  \
# 0                              NaN                      NaN
# 1                              9.0                     99.0
# 2                              NaN                      NaN
# 3                              7.0                      5.0
# 4                              9.0                      5.0
#
#    (P10*R2AS) - Hablemos a continuación de cuestiones relativas a la movilidad y la seguridad en la ciudad  ¿qué medio o medios de transporte utiliza habitualmente para sus desplazamientos cotidianos (desplazamientos al lugar de trabajo, estudio u otros co  \
# 0                                                1.0
# 1                                                NaN
# 2                                                1.0
# 3                                                NaN
# 4                                                NaN
#
#    Unnamed: 94  Unnamed: 95  Unnamed: 96  Unnamed: 97  Unnamed: 98  \
# 0          NaN          3.0          4.0          NaN          NaN
# 1          NaN          NaN          NaN          NaN          NaN
# 2          NaN          3.0          NaN          5.0          6.0
# 3          NaN          NaN          NaN          NaN          NaN
# 4          NaN          NaN          NaN          NaN          NaN
#
#    Unnamed: 99  Unnamed: 100  Unnamed: 101  Unnamed: 102  Unnamed: 103  \
# 0          NaN           8.0           NaN           NaN           NaN
# 1          NaN           NaN           NaN           NaN           NaN
# 2          7.0           8.0           9.0           NaN           NaN
# 3          NaN           NaN           NaN           NaN           NaN
# 4          NaN           NaN           NaN           NaN           NaN
#
#    Unnamed: 104  Unnamed: 105  Unnamed: 106  (P11*M10S) - b - Durante el día  \
# 0           NaN           NaN           NaN                              NaN
# 1           NaN           NaN           NaN                              9.0
# 2           NaN           NaN           NaN                              NaN
# 3           NaN           NaN           NaN                              8.0
# 4           NaN           NaN           NaN                              9.0
#
#    (P11*M10S) - c - Durante la noche  (P11*M10S) - a - Y en general  \
# 0                                NaN                            NaN
# 1                                7.0                            8.0
# 2                                NaN                            NaN
# 3                                7.0                            7.0
# 4                                7.0                            8.0
#
#    (P12*M10S) - b - Durante el día  (P12*M10S) - c - Durante la noche  \
# 0                              NaN                                NaN
# 1                              9.0                                9.0
# 2                              NaN                                NaN
# 3                              6.0                                9.0
# 4                              8.0                                8.0
#
#    (P13*M10S) - b - Durante el día  (P13*M10S) - c - Durante la noche  \
# 0                              NaN                                NaN
# 1                              9.0                                9.0
# 2                              NaN                                NaN
# 3                              7.0                                8.0
# 4                             10.0                               10.0
#
#    (P14*R10S) - Trataremos a continuación de la administración y el gobierno del ayuntamiento de Madrid  en la misma escala, ¿en qué medida se considera usted  informado/a  de lo que hace el ayuntamiento de Madrid?  \
# 0                                                NaN
# 1                                                9.0
# 2                                                NaN
# 3                                                6.0
# 4                                                8.0
#
#    (P15*M10S) - a - Las oficinas de atención a la ciudadanía de línea Madrid  \
# 0                                                NaN
# 1                                                9.0
# 2                                                NaN
# 3                                                6.0
# 4                                               99.0
#
#    (P15*M10S) - b - El teléfono 010  \
# 0                               NaN
# 1                              10.0
# 2                               NaN
# 3                              99.0
# 4                               9.0
#
#    (P15*M10S) - c - La web del ayuntamiento de Madrid: www.madrid.es  \
# 0                                                NaN
# 1                                                9.0
# 2                                                NaN
# 3                                                7.0
# 4                                                9.0
#
#    (P15*M10S) - d - Aplicaciones del ayuntamiento para dispositivos móviles (app para móviles, Madrid móvil, emt Madrid…)  \
# 0                                                NaN
# 1                                               10.0
# 2                                                NaN
# 3                                                7.0
# 4                                               99.0
#
#    (P15*M10S) - e - Las oficinas de atención al contribuyente  \
# 0                                                NaN
# 1                                                9.0
# 2                                                NaN
# 3                                                6.0
# 4                                               99.0
#
#    (P15*M10S) - f - Chat on line de línea Madrid  \
# 0                                            NaN
# 1                                           99.0
# 2                                            NaN
# 3                                           99.0
# 4                                           99.0
#
#    (P15*M10S) - g - Atención directa a las personas mayores, con número preferente y atención presencial sin cita previa  \
# 0                                                NaN
# 1                                               10.0
# 2                                                NaN
# 3                                                8.0
# 4                                               10.0
#
#    (P16*M10S) - a - Administración general del estado  \
# 0                                                9.0
# 1                                                NaN
# 2                                                2.0
# 3                                                NaN
# 4                                                NaN
#
#    (P16*M10S) - b - Administración de la comunidad de Madrid  \
# 0                                                8.0
# 1                                                NaN
# 2                                                5.0
# 3                                                NaN
# 4                                                NaN
#
#    (P16*M10S) - c - Administración del ayuntamiento de Madrid  \
# 0                                                8.0
# 1                                                NaN
# 2                                                4.0
# 3                                                NaN
# 4                                                NaN
#
#    (P17*R10S) - ¿Y en términos generales, en una escala de 0 a 10 ¿cómo calificaría usted la gestión que está realizando el equipo de gobierno del ayuntamiento de Madrid?  \
# 0                                                6.0
# 1                                                NaN
# 2                                                6.0
# 3                                                NaN
# 4                                                NaN
#
#    (P18*R10S) - En una escala de 0 a 10, ¿cómo está de satisfecho/a con la administración del ayuntamiento de Madrid?  \
# 0                                                5.0
# 1                                                NaN
# 2                                                6.0
# 3                                                NaN
# 4                                                NaN
#
#    (P19*R10S) - Poniendo en relación los impuestos que paga al ayuntamiento y los servicios que recibe. En una escala de 0 a 10 ¿cómo de satisfecho/a está?  \
# 0                                                NaN
# 1                                                9.0
# 2                                                NaN
# 3                                                8.0
# 4                                                8.0
#
#    (P20*M2AS) - a - Primero  (P20*M2AS) - b - Segundo  \
# 0                       NaN                       NaN
# 1                       7.0                       6.0
# 2                       NaN                       NaN
# 3                       1.0                       6.0
# 4                       6.0                       1.0
#
#    (P21*R1AS) - Y para terminar, a efectos de analísis estadístico, voy a hacerle algunas preguntas. ¿Podría indicarme su nacionalidad?  \
# 0                                                  1
# 1                                                  1
# 2                                                  1
# 3                                                  1
# 4                                                  1
#
#    (P22*R1AE) - ¿Cuáles son los estudios de más alto nivel oficial que usted ha cursado (con independencia de que los haya terminado o no)?  \
# 0                                                  6
# 1                                                  6
# 2                                                  6
# 3                                                  5
# 4                                                  5
#
#    (P23*R1AS) - ¿En cuál de las siguientes situaciones se encuentra usted actualmente? situación principal.  \
# 0                                                  1
# 1                                                  1
# 2                                                  1
# 3                                                  1
# 4                                                  4
#
#    (P24*R1AE) - ¿Y podría decirme a qué partido o coalición votó en las elecciones municipales de mayo de 2023?  \
# 0                                                 10
# 1                                                  1
# 2                                                  7
# 3                                                  5
# 4                                                  1
#
#   Ponderacion
# 0    1,236126
# 1    0,787242
# 2    1,270241
# 3    0,692541
# 4    1,023298

# %%
df.shape
# Out:
# (8593, 135)

# %%
df.columns
# Out:
# Index(['estudio', 'FechaInicio', 'HoraInicio', 'FechaFin', 'HoraFin',
#        'Duración', 'NúmeroEntrevista', 'DISTRITO',
#        '(P0B*R1AE) - Sexo (anotar)', '(P0D*R1AS) - ¿Me puede decir su edad?',
#        ...
#        '(P17*R10S) - ¿Y en términos generales, en una escala de 0 a 10 ¿cómo calificaría usted la gestión que está realizando el equipo de gobierno del ayuntamiento de Madrid?',
#        '(P18*R10S) - En una escala de 0 a 10, ¿cómo está de satisfecho/a con la administración del ayuntamiento de Madrid?',
#        '(P19*R10S) - Poniendo en relación los impuestos que paga al ayuntamiento y los servicios que recibe. En una escala de 0 a 10 ¿cómo de satisfecho/a está?',
#        '(P20*M2AS) - a - Primero', '(P20*M2AS) - b - Segundo',
#        '(P21*R1AS) - Y para terminar, a efectos de analísis estadístico, voy a hacerle algunas preguntas. ¿Podría indicarme su nacionalidad?',
#        '(P22*R1AE) - ¿Cuáles son los estudios de más alto nivel oficial que usted ha cursado (con independencia de que los haya terminado o no)?',
#        '(P23*R1AS) - ¿En cuál de las siguientes situaciones se encuentra usted actualmente? situación principal.',
#        '(P24*R1AE) - ¿Y podría decirme a qué partido o coalición votó en las elecciones municipales de mayo de 2023?',
#        'Ponderacion'],
#       dtype='str', length=135)

# %%
# Revisión general por columna
print("ANÁLISIS POR COLUMNA\n")
for columna in df.columns:
    print("Columna: ", columna)
    print("Tipo de dato: ", df[columna].dtype)
    print(f"Porcentaje de nulos: {round(df[columna].isnull().mean() * 100, 2)}%")
    print("Valores únicos: ", df[columna].unique())
    print("Número de valores únicos: ", df[columna].nunique())
    print("----------------------\n")
# Out:
# ANÁLISIS POR COLUMNA
#
# Columna:  estudio
# Tipo de dato:  str
# Porcentaje de nulos: 0.0%
# Valores únicos:  <StringArray>
# ['10409_CAL_VIDA_25Dist']
# Length: 1, dtype: str
# Número de valores únicos:  1
# ----------------------
#
# Columna:  FechaInicio
# Tipo de dato:  str
# Porcentaje de nulos: 0.0%
# Valores únicos:  <StringArray>
# ['19-sep-25', '20-sep-25', '22-sep-25', '23-sep-25', '24-sep-25', '25-sep-25',
#  '26-sep-25', '27-sep-25', '29-sep-25', '30-sep-25', '01-oct-25', '02-oct-25',
#  '03-oct-25', '04-oct-25', '06-oct-25', '07-oct-25', '08-oct-25', '09-oct-25',
#  '10-oct-25', '11-oct-25', '13-oct-25', '14-oct-25', '15-oct-25', '16-oct-25',
#  '17-oct-25', '18-oct-25', '20-oct-25', '21-oct-25', '22-oct-25', '23-oct-25',
#  '24-oct-25', '25-oct-25', '27-oct-25', '28-oct-25', '29-oct-25', '30-oct-25']
# Length: 36, dtype: str
# Número de valores únicos:  36
# ----------------------
#
# Columna:  HoraInicio
# Tipo de dato:  str
# Porcentaje de nulos: 0.0%
# Valores únicos:  <StringArray>
# ['13:28:13', '13:29:37', '13:29:50', '13:29:52', '13:30:16', '13:31:59',
#  '13:32:22', '13:32:23', '13:33:38', '13:35:45',
#  ...
#  '12:18:56', '12:23:31', '12:24:25', '12:29:49', '12:38:19', '12:44:59',
#  '12:59:32', '13:08:27', '13:19:06', '13:22:38']
# Length: 7704, dtype: str
# Número de valores únicos:  7704
# ----------------------
#
# Columna:  FechaFin
# Tipo de dato:  str
# Porcentaje de nulos: 0.0%
# Valores únicos:  <StringArray>
# ['19-sep-25', '20-sep-25', '22-sep-25', '23-sep-25', '24-sep-25', '25-sep-25',
#  '26-sep-25', '27-sep-25', '29-sep-25', '30-sep-25', '01-oct-25', '02-oct-25',
#  '03-oct-25', '04-oct-25', '06-oct-25', '07-oct-25', '08-oct-25', '09-oct-25',
#  '10-oct-25', '11-oct-25', '13-oct-25', '14-oct-25', '15-oct-25', '16-oct-25',
#  '17-oct-25', '18-oct-25', '20-oct-25', '21-oct-25', '22-oct-25', '23-oct-25',
#  '24-oct-25', '25-oct-25', '27-oct-25', '28-oct-25', '29-oct-25', '30-oct-25']
# Length: 36, dtype: str
# Número de valores únicos:  36
# ----------------------
#
# Columna:  HoraFin
# Tipo de dato:  str
# Porcentaje de nulos: 0.0%
# Valores únicos:  <StringArray>
# ['13:43:06', '13:44:01', '13:44:29', '13:44:18', '13:45:40', '13:48:33',
#  '13:49:32', '13:48:34', '13:47:15', '13:50:28',
#  ...
#  '12:33:25', '12:33:56', '12:38:14', '12:37:55', '12:39:49', '12:46:44',
#  '12:59:27', '13:06:45', '13:35:40', '13:41:21']
# Length: 7720, dtype: str
# Número de valores únicos:  7720
# ----------------------
#
# Columna:  Duración
# Tipo de dato:  str
# Porcentaje de nulos: 0.0%
# Valores únicos:  <StringArray>
# ['0:14:53', '0:14:24', '0:14:39', '0:14:26', '0:15:24', '0:16:34', '0:17:10',
#  '0:16:11', '0:13:37', '0:14:43',
#  ...
#  '0:26:22', '0:20:11', '0:31:37', '0:26:29', '0:39:31', '0:21:01', '0:33:55',
#  '0:22:22', '0:24:22', '0:25:52']
# Length: 689, dtype: str
# Número de valores únicos:  689
# ----------------------
#
# Columna:  NúmeroEntrevista
# Tipo de dato:  int64
# Porcentaje de nulos: 0.0%
# Valores únicos:  [1449659 1449660 1449661 ... 1458249 1458250 1458251]
# Número de valores únicos:  8593
# ----------------------
#
# Columna:  DISTRITO
# Tipo de dato:  int64
# Porcentaje de nulos: 0.0%
# Valores únicos:  [ 2  4  8  5 20  1  6 16 12 15  7  9 17 11  3 21 10 18 19 14 13]
# Número de valores únicos:  21
# ----------------------
#
# Columna:  (P0B*R1AE) - Sexo (anotar)
# Tipo de dato:  int64
# Porcentaje de nulos: 0.0%
# Valores únicos:  [1 2]
# Número de valores únicos:  2
# ----------------------
#
# Columna:  (P0D*R1AS) - ¿Me puede decir su edad?
# Tipo de dato:  int64
# Porcentaje de nulos: 0.0%
# Valores únicos:  [1 4 3 2 5]
# Número de valores únicos:  5
# ----------------------
#
# Columna:  P0F*R1AS) - Actualmente, ¿está viviendo en...?
# Tipo de dato:  int64
# Porcentaje de nulos: 0.0%
# Valores únicos:  [1 4 3 5 2]
# Número de valores únicos:  5
# ----------------------
#
# Columna:  (P1*M1AS) - a - En Madrid
# Tipo de dato:  int64
# Porcentaje de nulos: 0.0%
# Valores únicos:  [ 9 10  7  8  6  3  5  4  1  2  0]
# Número de valores únicos:  11
# ----------------------
#
# Columna:  (P1*M1AS) - b - En su distrito
# Tipo de dato:  int64
# Porcentaje de nulos: 0.0%
# Valores únicos:  [ 9  8  7 10  5  6  4  3  0  2  1 99]
# Número de valores únicos:  12
# ----------------------
#
# Columna:  (P1*M1AS) - c - En su barrio
# Tipo de dato:  int64
# Porcentaje de nulos: 0.0%
# Valores únicos:  [ 9 10  8  7  5  6  4  3 99  0  2  1]
# Número de valores únicos:  12
# ----------------------
#
# Columna:  (P2*M10S) - a - En Madrid
# Tipo de dato:  int64
# Porcentaje de nulos: 0.0%
# Valores únicos:  [ 8  9  7 10  5  3  6  1  4  2  0]
# Número de valores únicos:  11
# ----------------------
#
# Columna:  (P2*M10S) - b - En su distrito
# Tipo de dato:  int64
# Porcentaje de nulos: 0.0%
# Valores únicos:  [ 8  9  7 10  5  4  6  3  0  2 99  1]
# Número de valores únicos:  12
# ----------------------
#
# Columna:  (P2*M10S) - c - En su barrio
# Tipo de dato:  int64
# Porcentaje de nulos: 0.0%
# Valores únicos:  [ 9  8  7 10  5  3  6  4  0  2  1 99]
# Número de valores únicos:  12
# ----------------------
#
# Columna:  (P3*M10S) - a - En Madrid
# Tipo de dato:  int64
# Porcentaje de nulos: 0.0%
# Valores únicos:  [ 8 10  7  6  9  2  5  3  1  0  4]
# Número de valores únicos:  11
# ----------------------
#
# Columna:  (P3*M10S) - b - En su distrito
# Tipo de dato:  int64
# Porcentaje de nulos: 0.0%
# Valores únicos:  [ 9 10  8 99  7  3  6  5  1  4  0  2]
# Número de valores únicos:  12
# ----------------------
#
# Columna:  (P3*M10S) - c - En su barrio
# Tipo de dato:  int64
# Porcentaje de nulos: 0.0%
# Valores únicos:  [10  9  8  3  4  6  5  7  1  0  2]
# Número de valores únicos:  11
# ----------------------
#
# Columna:  (P4*M10S) - a - Cuidado y conservación de la ciudad
# Tipo de dato:  int64
# Porcentaje de nulos: 0.0%
# Valores únicos:  [ 8  5  7  9 10  6  4  2 99  0  3  1]
# Número de valores únicos:  12
# ----------------------
#
# Columna:  (P4*M10S) - b - Movilidad y transporte público
# Tipo de dato:  int64
# Porcentaje de nulos: 0.0%
# Valores únicos:  [10  7  8  9  4  5  6 99  2  3  1  0]
# Número de valores únicos:  12
# ----------------------
#
# Columna:  (P4*M10S) - c - Calidad medioambiental
# Tipo de dato:  int64
# Porcentaje de nulos: 0.0%
# Valores únicos:  [ 9  7  5  6  8  4  3  2  0 99  1 10]
# Número de valores únicos:  12
# ----------------------
#
# Columna:  (P4*M10S) - d - Facilidad para encontrar un trabajo
# Tipo de dato:  int64
# Porcentaje de nulos: 0.0%
# Valores únicos:  [ 8  9  5  7 10  6  3 99  2  0  4  1]
# Número de valores únicos:  12
# ----------------------
#
# Columna:  (P4*M10S) - e - Facilidad para emprender un negocio
# Tipo de dato:  int64
# Porcentaje de nulos: 0.0%
# Valores únicos:  [99  9  5  6  7 10  3  4  1  8  0  2]
# Número de valores únicos:  12
# ----------------------
#
# Columna:  (P4*M10S) - f - Imagen internacional de Madrid
# Tipo de dato:  int64
# Porcentaje de nulos: 0.0%
# Valores únicos:  [ 9 10  8  7  5  4  6  0  1  2 99  3]
# Número de valores únicos:  12
# ----------------------
#
# Columna:  (P4*M10S) - g - Coste de la vida
# Tipo de dato:  int64
# Porcentaje de nulos: 0.0%
# Valores únicos:  [ 5  7  9  4  2 10  1  3  6  0  8 99]
# Número de valores únicos:  12
# ----------------------
#
# Columna:  (P4*M10S) - h - Integración social
# Tipo de dato:  int64
# Porcentaje de nulos: 0.0%
# Valores únicos:  [ 8  7 99  9  5  6  3 10  1  0  4  2]
# Número de valores únicos:  12
# ----------------------
#
# Columna:  (P4*M10S) - i - Salud y servicios sanitarios
# Tipo de dato:  int64
# Porcentaje de nulos: 0.0%
# Valores únicos:  [ 8  5  7  9 10  6  3  4  1  0  2 99]
# Número de valores únicos:  12
# ----------------------
#
# Columna:  (P4*M10S) - j - Educación y centros educativos
# Tipo de dato:  int64
# Porcentaje de nulos: 0.0%
# Valores únicos:  [ 8  7 99 10  9  4  5  0  2  6  3  1]
# Número de valores únicos:  12
# ----------------------
#
# Columna:  (P4*M10S) - k - Facilidad para encontrar una vivienda en el marco de sus posibilidades
# Tipo de dato:  int64
# Porcentaje de nulos: 0.0%
# Valores únicos:  [ 4  7  2  6  3 10 99  0  1  5  8  9]
# Número de valores únicos:  12
# ----------------------
#
# Columna:  (P4*M10S) - l - Facilidad para hacer deporte
# Tipo de dato:  int64
# Porcentaje de nulos: 0.0%
# Valores únicos:  [10  9  7  8  5  4 99  3  0  2  6  1]
# Número de valores únicos:  12
# ----------------------
#
# Columna:  (P4*M10S) - m - Oferta cultural, ocio y diversión
# Tipo de dato:  int64
# Porcentaje de nulos: 0.0%
# Valores únicos:  [10  8  7  6  9  4  0  3  5  2 99  1]
# Número de valores únicos:  12
# ----------------------
#
# Columna:  (P4*M10S) - n - Convivencia vecinal
# Tipo de dato:  int64
# Porcentaje de nulos: 0.0%
# Valores únicos:  [ 7  8 10  5  6  4  9 99  2  0  3  1]
# Número de valores únicos:  12
# ----------------------
#
# Columna:  (P4*M10S) - o - Seguridad
# Tipo de dato:  int64
# Porcentaje de nulos: 0.0%
# Valores únicos:  [ 9  8  7  5 10  6  4  2  3 99  0  1]
# Número de valores únicos:  12
# ----------------------
#
# Columna:  (P5A*R1AE) - ¿Cuáles son, a su juicio y por orden de prioridad, los tres problemas principales que existen actualmente en la ciudad de Madrid? (anotar 1ª problema)
# Tipo de dato:  float64
# Porcentaje de nulos: 50.7%
# Valores únicos:  [ 4. nan 13.  5. 97. 46. 38.  6.  2. 98. 16.  9.  7. 27.  8. 10. 99.  1.
#  21. 11.  3. 49. 65. 48. 32. 25. 23. 24. 31. 18. 40. 12. 37. 17. 47. 33.
#  58. 61. 14. 22. 19. 36. 45. 60. 15. 39. 26. 34. 20. 62. 56. 35. 57. 30.
#  41. 53.]
# Número de valores únicos:  55
# ----------------------
#
# Columna:  (P5B*R1AE) - Anotar 2ª problema
# Tipo de dato:  float64
# Porcentaje de nulos: 50.7%
# Valores únicos:  [97. nan  8.  3.  2. 99.  4.  5. 12. 98.  1. 27. 26.  6. 37. 16. 10. 34.
#  56. 14. 39. 17. 13. 21. 15. 65. 40.  7. 19. 32. 20. 11. 31. 25. 38. 18.
#  60. 36. 41. 23. 24. 61.  9. 46. 49. 22. 33. 35. 47. 57. 45. 55. 50. 53.
#  52. 58. 62. 64. 48. 51. 63.]
# Número de valores únicos:  60
# ----------------------
#
# Columna:  (P5C*R1AE) - Anotar 3ª problema
# Tipo de dato:  float64
# Porcentaje de nulos: 50.7%
# Valores únicos:  [99. nan 10. 65.  3.  7.  2. 97.  4. 16. 98.  5.  6. 40. 19. 26. 24.  9.
#   8. 27. 21. 12. 22.  1. 56. 50. 47. 25. 15. 46. 18. 13. 17. 31. 14. 20.
#  32. 61. 52. 39. 38. 49. 23. 36. 33. 55. 11. 51. 63. 37. 45. 58. 60. 35.
#  41. 57. 48. 54. 62. 53. 30. 34.]
# Número de valores únicos:  61
# ----------------------
#
# Columna:  P4_Total
# Tipo de dato:  str
# Porcentaje de nulos: 50.7%
# Valores únicos:  <StringArray>
# [ '4;97;99',        nan,   '4;8;10',  '13;3;65',    '5;2;3', '97;99;99',
#    '46;4;7',   '4;5;10',   '13;5;2',  '4;12;97',
#  ...
#    '4;1;21', '32;12;27',  '2;16;34',  '21;6;25',  '2;21;14',   '4;6;27',
#     '4;7;1',  '4;38;97',   '25;5;4',   '5;2;18']
# Length: 2105, dtype: str
# Número de valores únicos:  2104
# ----------------------
#
# Columna:  (P6*M10S) - a - Desigualdad de oportunidades entre hombres y mujeres
# Tipo de dato:  float64
# Porcentaje de nulos: 50.7%
# Valores únicos:  [ 7. nan  5.  2.  0.  6. 10.  3. 99.  9.  4.  1.  8.]
# Número de valores únicos:  12
# ----------------------
#
# Columna:  (P6*M10S) - b - Desigualdad de oportunidades entre la población extranjera y autóctona
# Tipo de dato:  float64
# Porcentaje de nulos: 50.7%
# Valores únicos:  [ 7. nan 10.  2.  6.  0.  8.  5.  4. 99.  9.  3.  1.]
# Número de valores únicos:  12
# ----------------------
#
# Columna:  (P7*M10S) - a - Las personas mayores
# Tipo de dato:  float64
# Porcentaje de nulos: 50.7%
# Valores únicos:  [ 8. nan  5.  9.  7. 10.  6.  0.  2.  4. 99.  3.  1.]
# Número de valores únicos:  12
# ----------------------
#
# Columna:  (P7*M10S) - b - La infancia
# Tipo de dato:  float64
# Porcentaje de nulos: 50.7%
# Valores únicos:  [ 8. nan  5. 10.  7. 99.  6.  4.  9.  0.  2.  3.  1.]
# Número de valores únicos:  12
# ----------------------
#
# Columna:  (P7*M10S) - c - Las personas con discapacidad
# Tipo de dato:  float64
# Porcentaje de nulos: 50.7%
# Valores únicos:  [ 7. nan  5. 10.  6.  8.  0.  4.  3.  9. 99.  1.  2.]
# Número de valores únicos:  12
# ----------------------
#
# Columna:  (P7*M10S) - d - Las personas lgtbiq+
# Tipo de dato:  float64
# Porcentaje de nulos: 50.7%
# Valores únicos:  [ 8. nan  7.  9. 10. 99.  6.  5.  4.  3.  2.  0.  1.]
# Número de valores únicos:  12
# ----------------------
#
# Columna:  (P7*M10S) - e - Los migrantes
# Tipo de dato:  float64
# Porcentaje de nulos: 50.7%
# Valores únicos:  [ 7. nan  5.  1. 10.  6. 99.  8.  4.  3.  2.  9.  0.]
# Número de valores únicos:  12
# ----------------------
#
# Columna:  (7*M10S) - f - La adolescencia
# Tipo de dato:  float64
# Porcentaje de nulos: 50.7%
# Valores únicos:  [ 8. nan 10.  6. 99.  7.  5.  0.  3.  9.  2.  4.  1.]
# Número de valores únicos:  12
# ----------------------
#
# Columna:  (P8*M10S) - a - La recogida de basuras y contenedores
# Tipo de dato:  float64
# Porcentaje de nulos: 50.7%
# Valores únicos:  [ 8. nan  6.  1.  2.  7.  9. 10.  5.  0.  4.  3. 99.]
# Número de valores únicos:  12
# ----------------------
#
# Columna:  (P8*M10S) - b - La gestión y tratamiento de residuos (reciclaje, compostaje, etc.)
# Tipo de dato:  float64
# Porcentaje de nulos: 50.7%
# Valores únicos:  [ 8. nan  5.  2.  6.  4.  9.  0.  3. 99.  7.  1. 10.]
# Número de valores únicos:  12
# ----------------------
#
# Columna:  (P8*M10S) - c - El control de la contaminación atmosférica
# Tipo de dato:  float64
# Porcentaje de nulos: 50.7%
# Valores únicos:  [ 7. nan  5.  6.  3.  4.  8.  9.  0.  2. 10. 99.  1.]
# Número de valores únicos:  12
# ----------------------
#
# Columna:  (P8*M10S) - d - El control del ruido
# Tipo de dato:  float64
# Porcentaje de nulos: 50.7%
# Valores únicos:  [ 8. nan  5.  3.  6.  7.  4.  0.  9.  2. 99. 10.  1.]
# Número de valores únicos:  12
# ----------------------
#
# Columna:  (P8*M10S) - e - La limpieza de las calles
# Tipo de dato:  float64
# Porcentaje de nulos: 50.7%
# Valores únicos:  [ 8. nan  5.  7.  3.  9.  6.  4.  0.  2.  1. 10. 99.]
# Número de valores únicos:  12
# ----------------------
#
# Columna:  (P8*M10S) - f - El alumbrado público
# Tipo de dato:  float64
# Porcentaje de nulos: 50.7%
# Valores únicos:  [ 8. nan  5.  7.  6. 10.  9.  3.  4.  1.  2.  0. 99.]
# Número de valores únicos:  12
# ----------------------
#
# Columna:  (P8*M10S) - g - Las infraestructuras de la ciudad para la circulación de vehículos (calles, túneles, etc.…)
# Tipo de dato:  float64
# Porcentaje de nulos: 50.7%
# Valores únicos:  [ 9. nan  6.  8.  7. 10.  1.  0.  5.  3.  2. 99.  4.]
# Número de valores únicos:  12
# ----------------------
#
# Columna:  (P8*M10S) - h - La pavimentación y conservación de las aceras
# Tipo de dato:  float64
# Porcentaje de nulos: 50.7%
# Valores únicos:  [ 7. nan  2.  5.  6.  9.  0.  3.  4.  8. 10.  1. 99.]
# Número de valores únicos:  12
# ----------------------
#
# Columna:  (P8*M10S) - i - El asfaltado y conservación de las calzadas
# Tipo de dato:  float64
# Porcentaje de nulos: 50.7%
# Valores únicos:  [ 8. nan  2.  4.  6. 10.  7.  9.  3.  5.  0.  1. 99.]
# Número de valores únicos:  12
# ----------------------
#
# Columna:  (P8*M10S) - j - La peatonalización de calles
# Tipo de dato:  float64
# Porcentaje de nulos: 50.7%
# Valores únicos:  [ 8. nan  5.  7.  3. 10.  4.  0.  9.  6.  2.  1. 99.]
# Número de valores únicos:  12
# ----------------------
#
# Columna:  (P8*M10S) - k - La eliminación de barreras arquitectónicas (rebaje de bordillos, semáforos acústicos, etc.)
# Tipo de dato:  float64
# Porcentaje de nulos: 50.7%
# Valores únicos:  [ 7. nan  5.  6. 10.  4. 99.  8.  0.  3.  9.  2.  1.]
# Número de valores únicos:  12
# ----------------------
#
# Columna:  (P8*M10S) - l - La movilidad sostenible
# Tipo de dato:  float64
# Porcentaje de nulos: 50.7%
# Valores únicos:  [ 8. nan  5.  7.  6.  3. 99.  0.  4.  9.  2. 10.  1.]
# Número de valores únicos:  12
# ----------------------
#
# Columna:  (P8*M10S) - v - La mejora de la calidad del aire
# Tipo de dato:  float64
# Porcentaje de nulos: 50.7%
# Valores únicos:  [ 7. nan  5.  3.  6.  9.  2. 10.  4.  8.  0.  1. 99.]
# Número de valores únicos:  12
# ----------------------
#
# Columna:  (P8*M10S) - m - La conservación y rehabilitación de los edificios
# Tipo de dato:  float64
# Porcentaje de nulos: 50.7%
# Valores únicos:  [ 7. nan  5.  3.  6.  8. 10.  0.  2.  4. 99.  9.  1.]
# Número de valores únicos:  12
# ----------------------
#
# Columna:  (P8*M10S) - n - La protección de monumentos y del patrimonio histórico-artístico
# Tipo de dato:  float64
# Porcentaje de nulos: 50.7%
# Valores únicos:  [ 8. nan  7.  9. 10.  6.  5.  4. 99.  2.  0.  3.  1.]
# Número de valores únicos:  12
# ----------------------
#
# Columna:  (P8*M10S) - o - La información y promoción turística
# Tipo de dato:  float64
# Porcentaje de nulos: 50.7%
# Valores únicos:  [ 8. nan  7. 10.  5.  9.  0.  6.  2.  3. 99.  4.  1.]
# Número de valores únicos:  12
# ----------------------
#
# Columna:  (P8*M10S) - p - La organización de fiestas y eventos populares (cabalgata, fiestas de san isidro, fiestas de los distritos...)
# Tipo de dato:  float64
# Porcentaje de nulos: 50.7%
# Valores únicos:  [ 7. nan  6. 10.  8.  0.  4.  5.  9.  3.  2.  1. 99.]
# Número de valores únicos:  12
# ----------------------
#
# Columna:  (P8*M10S) - q - El control de la salud pública (plagas, alimentos, aguas...)
# Tipo de dato:  float64
# Porcentaje de nulos: 50.7%
# Valores únicos:  [ 7. nan  5.  6.  8. 10.  0. 99.  9.  4.  3.  2.  1.]
# Número de valores únicos:  12
# ----------------------
#
# Columna:  (P8*M10S) - r - Las ayudas e incentivos a pymes y autónomos
# Tipo de dato:  float64
# Porcentaje de nulos: 50.7%
# Valores únicos:  [ 9. nan  6.  5.  7.  3. 99.  0.  1.  4. 10.  2.  8.]
# Número de valores únicos:  12
# ----------------------
#
# Columna:  (P8*M10S) - s - La información al consumidor
# Tipo de dato:  float64
# Porcentaje de nulos: 50.7%
# Valores únicos:  [ 9. nan  8.  7.  5.  6.  4. 10. 99.  3.  2.  0.  1.]
# Número de valores únicos:  12
# ----------------------
#
# Columna:  (P8*M10S) - t - La promoción pública de viviendas
# Tipo de dato:  float64
# Porcentaje de nulos: 50.7%
# Valores únicos:  [ 5. nan  2.  8.  6.  1.  4.  0. 99.  9.  3.  7. 10.]
# Número de valores únicos:  12
# ----------------------
#
# Columna:  (P8*M10S) - w - La actuación frente a la ocupación ilegal
# Tipo de dato:  float64
# Porcentaje de nulos: 50.7%
# Valores únicos:  [ 8. nan  2.  1.  6.  0. 99.  9.  5.  4.  7.  3. 10.]
# Número de valores únicos:  12
# ----------------------
#
# Columna:  (P8*M10S) - u - Los beneficios fiscales promovidos por el ayuntamiento (bajada de impuestos, bonificaciones...)
# Tipo de dato:  float64
# Porcentaje de nulos: 50.7%
# Valores únicos:  [ 8. nan  4.  7.  5.  1.  2. 10.  6. 99.  9.  3.  0.]
# Número de valores únicos:  12
# ----------------------
#
# Columna:  (P8*M10S) - x - El plan de fomento de la natalidad y la conciliación (el cheque bebé)
# Tipo de dato:  float64
# Porcentaje de nulos: 50.7%
# Valores únicos:  [ 6. nan  5.  7.  8.  2. 99.  0.  1.  4. 10.  9.  3.]
# Número de valores únicos:  12
# ----------------------
#
# Columna:  (P9*M10S) - a - La atención a la ciudadanía
# Tipo de dato:  float64
# Porcentaje de nulos: 49.11%
# Valores únicos:  [nan  8.  7.  9.  5.  2.  6. 99.  0.  3.  4.  1. 10.]
# Número de valores únicos:  12
# ----------------------
#
# Columna:  (P9*M10S) - c - El servicio de autobuses de la Emt
# Tipo de dato:  float64
# Porcentaje de nulos: 49.11%
# Valores únicos:  [nan 10.  7.  9.  8.  6. 99.  3.  4.  5.  0.  2.  1.]
# Número de valores únicos:  12
# ----------------------
#
# Columna:  (P9*M10S) - d - Los taxis
# Tipo de dato:  float64
# Porcentaje de nulos: 49.11%
# Valores únicos:  [nan  8.  6.  7.  3.  4.  5. 99.  0.  9. 10.  2.  1.]
# Número de valores únicos:  12
# ----------------------
#
# Columna:  (P9*M10S) - e - El ser (servicio de estacionamiento regulado)
# Tipo de dato:  float64
# Porcentaje de nulos: 49.11%
# Valores únicos:  [nan  9.  8.  6.  7.  3.  0. 99.  4.  1.  5. 10.  2.]
# Número de valores únicos:  12
# ----------------------
#
# Columna:  (P9*M10S) - f - Los agentes de movilidad
# Tipo de dato:  float64
# Porcentaje de nulos: 49.11%
# Valores únicos:  [nan  8.  7.  6.  5.  4. 99.  0.  3. 10.  9.  1.  2.]
# Número de valores únicos:  12
# ----------------------
#
# Columna:  (P9*M10S) - g - La policía municipal
# Tipo de dato:  float64
# Porcentaje de nulos: 49.11%
# Valores únicos:  [nan  8.  9.  5.  6.  2.  7. 99.  0. 10.  4.  3.  1.]
# Número de valores únicos:  12
# ----------------------
#
# Columna:  (P9*M10S) - h - Los bomberos
# Tipo de dato:  float64
# Porcentaje de nulos: 49.11%
# Valores únicos:  [nan 10.  7.  6.  8. 99.  9.  0.  4.  5.  3.  2.  1.]
# Número de valores únicos:  12
# ----------------------
#
# Columna:  (P9*M10S) - i - Samur – protección civil
# Tipo de dato:  float64
# Porcentaje de nulos: 49.11%
# Valores únicos:  [nan  9.  6. 10. 99.  3.  8.  7.  0.  5.  1.  4.  2.]
# Número de valores únicos:  12
# ----------------------
#
# Columna:  (P9*M10S) - j - La beca infantil para la escolarización 0-3 años
# Tipo de dato:  float64
# Porcentaje de nulos: 49.11%
# Valores únicos:  [nan  9.  8. 99. 10.  7.  6.  1.  0.  2.  4.  5.  3.]
# Número de valores únicos:  12
# ----------------------
#
# Columna:  (P9*M10S) - k - Los servicios sociales municipales (mayores, personas con discapacidad, inmigrantes, familias, …)
# Tipo de dato:  float64
# Porcentaje de nulos: 49.11%
# Valores únicos:  [nan  8.  9.  6.  5.  4.  7. 99.  0.  1.  3.  2. 10.]
# Número de valores únicos:  12
# ----------------------
#
# Columna:  (P9*M10S) - l - Las vías ciclistas
# Tipo de dato:  float64
# Porcentaje de nulos: 49.11%
# Valores únicos:  [nan  7.  5.  9.  4.  1.  6. 99.  0.  3.  8.  2. 10.]
# Número de valores únicos:  12
# ----------------------
#
# Columna:  (P9*M10S) - m - Los aparcamientos municipales
# Tipo de dato:  float64
# Porcentaje de nulos: 49.11%
# Valores únicos:  [nan  9.  8.  7.  6. 99.  1.  0. 10.  3.  5.  4.  2.]
# Número de valores únicos:  12
# ----------------------
#
# Columna:  (P9*M10S) - n - Los puntos limpios de recogida y reciclaje de residuos
# Tipo de dato:  float64
# Porcentaje de nulos: 49.11%
# Valores únicos:  [nan  9.  5.  7.  8. 10.  6.  0.  1.  4.  2. 99.  3.]
# Número de valores únicos:  12
# ----------------------
#
# Columna:  (P9*M10S) - o - Los espacios verdes (parques y jardines)
# Tipo de dato:  float64
# Porcentaje de nulos: 49.11%
# Valores únicos:  [nan  8.  7.  9.  5.  6.  3.  4. 10.  2.  1.  0. 99.]
# Número de valores únicos:  12
# ----------------------
#
# Columna:  (P9*M10S) - p - Los parques infantiles
# Tipo de dato:  float64
# Porcentaje de nulos: 49.11%
# Valores únicos:  [nan  8.  7.  3.  6. 99.  4. 10.  0.  5.  9.  2.  1.]
# Número de valores únicos:  12
# ----------------------
#
# Columna:  (P9*M10S) - q - Los mercados municipales
# Tipo de dato:  float64
# Porcentaje de nulos: 49.11%
# Valores únicos:  [nan  8.  9. 10.  5.  4.  7. 99.  0.  6.  2.  1.  3.]
# Número de valores únicos:  12
# ----------------------
#
# Columna:  (P9*M10S) - r - Las instalaciones deportivas municipales
# Tipo de dato:  float64
# Porcentaje de nulos: 49.11%
# Valores únicos:  [nan  8.  6. 10.  7.  9.  5.  0.  4. 99.  3.  1.  2.]
# Número de valores únicos:  12
# ----------------------
#
# Columna:  (P9*M10S) - s - Los centros culturales municipales
# Tipo de dato:  float64
# Porcentaje de nulos: 49.11%
# Valores únicos:  [nan  8.  7. 10.  5. 99.  0.  9.  6.  4.  2.  3.  1.]
# Número de valores únicos:  12
# ----------------------
#
# Columna:  (P9*M10S) - t - Las bibliotecas municipales
# Tipo de dato:  float64
# Porcentaje de nulos: 49.11%
# Valores únicos:  [nan  8. 10.  9.  3.  7.  5. 99.  6.  4.  2.  0.  1.]
# Número de valores únicos:  12
# ----------------------
#
# Columna:  (P9*M10S) - u - Los teatros municipales (Español, Matadero, Fernán Gómez…)
# Tipo de dato:  float64
# Porcentaje de nulos: 49.11%
# Valores únicos:  [nan  8.  9. 99.  4.  7.  6. 10.  3.  5.  1.  0.  2.]
# Número de valores únicos:  12
# ----------------------
#
# Columna:  (P9*M10S) - v - El Samur social
# Tipo de dato:  float64
# Porcentaje de nulos: 49.11%
# Valores únicos:  [nan  9.  7.  8. 10.  6. 99.  0.  4.  1.  5.  3.  2.]
# Número de valores únicos:  12
# ----------------------
#
# Columna:  (P9*M10S) - w - Bicimad
# Tipo de dato:  float64
# Porcentaje de nulos: 49.11%
# Valores únicos:  [nan 99.  5.  8.  7.  1.  2.  0.  6.  3.  4. 10.  9.]
# Número de valores únicos:  12
# ----------------------
#
# Columna:  (P10*R2AS) - Hablemos a continuación de cuestiones relativas a la movilidad y la seguridad en la ciudad  ¿qué medio o medios de transporte utiliza habitualmente para sus desplazamientos cotidianos (desplazamientos al lugar de trabajo, estudio u otros co
# Tipo de dato:  float64
# Porcentaje de nulos: 68.53%
# Valores únicos:  [ 1. nan]
# Número de valores únicos:  1
# ----------------------
#
# Columna:  Unnamed: 94
# Tipo de dato:  float64
# Porcentaje de nulos: 98.45%
# Valores únicos:  [nan  2.]
# Número de valores únicos:  1
# ----------------------
#
# Columna:  Unnamed: 95
# Tipo de dato:  float64
# Porcentaje de nulos: 66.76%
# Valores únicos:  [ 3. nan]
# Número de valores únicos:  1
# ----------------------
#
# Columna:  Unnamed: 96
# Tipo de dato:  float64
# Porcentaje de nulos: 89.76%
# Valores únicos:  [ 4. nan]
# Número de valores únicos:  1
# ----------------------
#
# Columna:  Unnamed: 97
# Tipo de dato:  float64
# Porcentaje de nulos: 74.82%
# Valores únicos:  [nan  5.]
# Número de valores únicos:  1
# ----------------------
#
# Columna:  Unnamed: 98
# Tipo de dato:  float64
# Porcentaje de nulos: 96.82%
# Valores únicos:  [nan  6.]
# Número de valores únicos:  1
# ----------------------
#
# Columna:  Unnamed: 99
# Tipo de dato:  float64
# Porcentaje de nulos: 92.92%
# Valores únicos:  [nan  7.]
# Número de valores únicos:  1
# ----------------------
#
# Columna:  Unnamed: 100
# Tipo de dato:  float64
# Porcentaje de nulos: 92.9%
# Valores únicos:  [ 8. nan]
# Número de valores únicos:  1
# ----------------------
#
# Columna:  Unnamed: 101
# Tipo de dato:  float64
# Porcentaje de nulos: 98.28%
# Valores únicos:  [nan  9.]
# Número de valores únicos:  1
# ----------------------
#
# Columna:  Unnamed: 102
# Tipo de dato:  float64
# Porcentaje de nulos: 97.56%
# Valores únicos:  [nan 10.]
# Número de valores únicos:  1
# ----------------------
#
# Columna:  Unnamed: 103
# Tipo de dato:  float64
# Porcentaje de nulos: 97.4%
# Valores únicos:  [nan 11.]
# Número de valores únicos:  1
# ----------------------
#
# Columna:  Unnamed: 104
# Tipo de dato:  float64
# Porcentaje de nulos: 98.86%
# Valores únicos:  [nan 12.]
# Número de valores únicos:  1
# ----------------------
#
# Columna:  Unnamed: 105
# Tipo de dato:  float64
# Porcentaje de nulos: 98.75%
# Valores únicos:  [nan 13.]
# Número de valores únicos:  1
# ----------------------
#
# Columna:  Unnamed: 106
# Tipo de dato:  float64
# Porcentaje de nulos: 99.97%
# Valores únicos:  [nan 99.]
# Número de valores únicos:  1
# ----------------------
#
# Columna:  (P11*M10S) - b - Durante el día
# Tipo de dato:  float64
# Porcentaje de nulos: 49.11%
# Valores únicos:  [nan  9.  8.  7. 10.  5.  6.  4.  2.  3.  0. 99.  1.]
# Número de valores únicos:  12
# ----------------------
#
# Columna:  (P11*M10S) - c - Durante la noche
# Tipo de dato:  float64
# Porcentaje de nulos: 49.11%
# Valores únicos:  [nan  7.  8.  6.  9.  4. 10.  3.  5.  2.  0.  1. 99.]
# Número de valores únicos:  12
# ----------------------
#
# Columna:  (P11*M10S) - a - Y en general
# Tipo de dato:  float64
# Porcentaje de nulos: 49.11%
# Valores únicos:  [nan  8.  7.  9.  2.  5. 10.  4.  6.  0.  1.  3. 99.]
# Número de valores únicos:  12
# ----------------------
#
# Columna:  (P12*M10S) - b - Durante el día
# Tipo de dato:  float64
# Porcentaje de nulos: 49.11%
# Valores únicos:  [nan  9.  6.  8. 10.  7.  5.  4.  1.  3.  0.  2. 99.]
# Número de valores únicos:  12
# ----------------------
#
# Columna:  (P12*M10S) - c - Durante la noche
# Tipo de dato:  float64
# Porcentaje de nulos: 49.11%
# Valores únicos:  [nan  9.  8. 10.  4.  6. 99.  7.  5.  0.  3.  2.  1.]
# Número de valores únicos:  12
# ----------------------
#
# Columna:  (P13*M10S) - b - Durante el día
# Tipo de dato:  float64
# Porcentaje de nulos: 49.11%
# Valores únicos:  [nan  9.  7. 10.  8.  5.  6.  4.  1.  0.  3.  2. 99.]
# Número de valores únicos:  12
# ----------------------
#
# Columna:  (P13*M10S) - c - Durante la noche
# Tipo de dato:  float64
# Porcentaje de nulos: 49.11%
# Valores únicos:  [nan  9.  8. 10.  5.  7.  3.  4.  0.  6.  2.  1. 99.]
# Número de valores únicos:  12
# ----------------------
#
# Columna:  (P14*R10S) - Trataremos a continuación de la administración y el gobierno del ayuntamiento de Madrid  en la misma escala, ¿en qué medida se considera usted  informado/a  de lo que hace el ayuntamiento de Madrid?
# Tipo de dato:  float64
# Porcentaje de nulos: 49.11%
# Valores únicos:  [nan  9.  6.  8.  7.  0.  1. 99.  5.  4.  2.  3. 10.]
# Número de valores únicos:  12
# ----------------------
#
# Columna:  (P15*M10S) - a - Las oficinas de atención a la ciudadanía de línea Madrid
# Tipo de dato:  float64
# Porcentaje de nulos: 49.11%
# Valores únicos:  [nan  9.  6. 99.  3.  5.  0.  7.  4.  2.  8.  1. 10.]
# Número de valores únicos:  12
# ----------------------
#
# Columna:  (P15*M10S) - b - El teléfono 010
# Tipo de dato:  float64
# Porcentaje de nulos: 49.11%
# Valores únicos:  [nan 10. 99.  9.  4.  2.  8.  6.  7.  0.  5.  1.  3.]
# Número de valores únicos:  12
# ----------------------
#
# Columna:  (P15*M10S) - c - La web del ayuntamiento de Madrid: www.madrid.es
# Tipo de dato:  float64
# Porcentaje de nulos: 49.11%
# Valores únicos:  [nan  9.  7.  8.  5.  4.  6. 99.  0. 10.  3.  2.  1.]
# Número de valores únicos:  12
# ----------------------
#
# Columna:  (P15*M10S) - d - Aplicaciones del ayuntamiento para dispositivos móviles (app para móviles, Madrid móvil, emt Madrid…)
# Tipo de dato:  float64
# Porcentaje de nulos: 49.11%
# Valores únicos:  [nan 10.  7. 99.  6.  9.  5.  0.  3.  4.  8.  1.  2.]
# Número de valores únicos:  12
# ----------------------
#
# Columna:  (P15*M10S) - e - Las oficinas de atención al contribuyente
# Tipo de dato:  float64
# Porcentaje de nulos: 49.11%
# Valores únicos:  [nan  9.  6. 99.  7.  2.  0.  8.  3.  4.  5.  1. 10.]
# Número de valores únicos:  12
# ----------------------
#
# Columna:  (P15*M10S) - f - Chat on line de línea Madrid
# Tipo de dato:  float64
# Porcentaje de nulos: 49.11%
# Valores únicos:  [nan 99.  5.  9. 10.  6.  0.  3.  4.  2.  7.  8.  1.]
# Número de valores únicos:  12
# ----------------------
#
# Columna:  (P15*M10S) - g - Atención directa a las personas mayores, con número preferente y atención presencial sin cita previa
# Tipo de dato:  float64
# Porcentaje de nulos: 49.11%
# Valores únicos:  [nan 10.  8.  6.  7. 99.  5.  0.  4.  2.  3.  9.  1.]
# Número de valores únicos:  12
# ----------------------
#
# Columna:  (P16*M10S) - a - Administración general del estado
# Tipo de dato:  float64
# Porcentaje de nulos: 50.7%
# Valores únicos:  [ 9. nan  2.  3. 10.  5.  1.  6.  7.  0.  8.  4. 99.]
# Número de valores únicos:  12
# ----------------------
#
# Columna:  (P16*M10S) - b - Administración de la comunidad de Madrid
# Tipo de dato:  float64
# Porcentaje de nulos: 50.7%
# Valores únicos:  [ 8. nan  5.  9.  6.  1. 10.  2.  0.  4.  7.  3. 99.]
# Número de valores únicos:  12
# ----------------------
#
# Columna:  (P16*M10S) - c - Administración del ayuntamiento de Madrid
# Tipo de dato:  float64
# Porcentaje de nulos: 50.7%
# Valores únicos:  [ 8. nan  4.  9.  7.  5. 10.  2.  3.  0.  6. 99.  1.]
# Número de valores únicos:  12
# ----------------------
#
# Columna:  (P17*R10S) - ¿Y en términos generales, en una escala de 0 a 10 ¿cómo calificaría usted la gestión que está realizando el equipo de gobierno del ayuntamiento de Madrid?
# Tipo de dato:  float64
# Porcentaje de nulos: 50.7%
# Valores únicos:  [ 6. nan  9.  7. 10.  8.  0.  2.  4.  1.  3.  5. 99.]
# Número de valores únicos:  12
# ----------------------
#
# Columna:  (P18*R10S) - En una escala de 0 a 10, ¿cómo está de satisfecho/a con la administración del ayuntamiento de Madrid?
# Tipo de dato:  float64
# Porcentaje de nulos: 50.7%
# Valores únicos:  [ 5. nan  6.  9.  7. 10.  3.  8.  1.  0.  4.  2. 99.]
# Número de valores únicos:  12
# ----------------------
#
# Columna:  (P19*R10S) - Poniendo en relación los impuestos que paga al ayuntamiento y los servicios que recibe. En una escala de 0 a 10 ¿cómo de satisfecho/a está?
# Tipo de dato:  float64
# Porcentaje de nulos: 49.11%
# Valores únicos:  [nan  9.  8.  7.  2.  4.  3.  6.  1.  5.  0. 10. 99.]
# Número de valores únicos:  12
# ----------------------
#
# Columna:  (P20*M2AS) - a - Primero
# Tipo de dato:  float64
# Porcentaje de nulos: 49.11%
# Valores únicos:  [nan  7.  1.  6.  4. 10.  3. 11.  9. 13.  5. 12.  2. 97.  8. 99. 14.]
# Número de valores únicos:  16
# ----------------------
#
# Columna:  (P20*M2AS) - b - Segundo
# Tipo de dato:  float64
# Porcentaje de nulos: 49.11%
# Valores únicos:  [nan  6.  1.  5.  3.  7.  9.  2. 11.  8. 12.  4. 10. 13. 97. 14. 99.]
# Número de valores únicos:  16
# ----------------------
#
# Columna:  (P21*R1AS) - Y para terminar, a efectos de analísis estadístico, voy a hacerle algunas preguntas. ¿Podría indicarme su nacionalidad?
# Tipo de dato:  int64
# Porcentaje de nulos: 0.0%
# Valores únicos:  [ 1  5 12 17  2 42  4  3 16  8 14  6 99 20 25  7 41 59 11 15 98 36 19 23
#  30 27 29 63 18 48 10 62 21 26  9 13 47 52 38 58 56 51 33 31 55 49 53 64
#  61 57 54 60 50 39 40]
# Número de valores únicos:  55
# ----------------------
#
# Columna:  (P22*R1AE) - ¿Cuáles son los estudios de más alto nivel oficial que usted ha cursado (con independencia de que los haya terminado o no)?
# Tipo de dato:  int64
# Porcentaje de nulos: 0.0%
# Valores únicos:  [ 6  5  4  3  2 99  1]
# Número de valores únicos:  7
# ----------------------
#
# Columna:  (P23*R1AS) - ¿En cuál de las siguientes situaciones se encuentra usted actualmente? situación principal.
# Tipo de dato:  int64
# Porcentaje de nulos: 0.0%
# Valores únicos:  [ 1  4  2  6 98  7  3 99  5]
# Número de valores únicos:  9
# ----------------------
#
# Columna:  (P24*R1AE) - ¿Y podría decirme a qué partido o coalición votó en las elecciones municipales de mayo de 2023?
# Tipo de dato:  int64
# Porcentaje de nulos: 0.0%
# Valores únicos:  [10  1  7  5  2  3  8 99  4 97  6  9 11]
# Número de valores únicos:  13
# ----------------------
#
# Columna:  Ponderacion
# Tipo de dato:  str
# Porcentaje de nulos: 0.0%
# Valores únicos:  <StringArray>
# ['1,236126', '0,787242', '1,270241', '0,692541', '1,023298',  '0,94273',
#  '0,920725', '0,735759', '1,209711', '1,484672',
#  ...
#  '0,639597', '1,269586', '0,912254', '0,775247', '0,533819', '0,878417',
#  '0,803832', '1,235885', '0,996016', '1,895905']
# Length: 210, dtype: str
# Número de valores únicos:  210
# ----------------------

# %%
columnas_eliminar = ['estudio', 'HoraInicio', 'FechaFin', 'HoraFin', 'Duración', '(P1*M1AS) - a - En Madrid', '(P2*M10S) - a - En Madrid', 'Columna:  (P3*M10S) - a - En Madrid', '(P5A*R1AE) - ¿Cuáles son, a su juicio y por orden de prioridad, los tres problemas principales que existen actualmente en la ciudad de Madrid? (anotar 1ª problema)', 'Columna:  (P5B*R1AE) - Anotar 2ª problema', '(P5C*R1AE) - Anotar 3ª problema', 'P4_Total', 'Columna:  (P8*M10S) - o - La información y promoción turística', 'La organización de fiestas y eventos populares (cabalgata, fiestas de san isidro, fiestas de los distritos...)', '(P8*M10S) - s - La información al consumidor', 'Unnamed: 94', 'Unnamed: 95', 'Unnamed: 96', 'Unnamed: 97', 'Unnamed: 98', 'Unnamed: 99', 'Unnamed: 100', 'Unnamed: 101', 'Unnamed: 102', 'Unnamed: 103', 'Unnamed: 104', 'Unnamed: 105', 'Unnamed: 106', '(P10*R2AS) - Hablemos a continuación de cuestiones relativas a la movilidad y la seguridad en la ciudad  ¿qué medio o medios de transporte utiliza habitualmente para sus desplazamientos cotidianos (desplazamientos al lugar de trabajo, estudio u otros co']

# %%
df_limpio = df.drop(columns=columnas_eliminar, errors='ignore')

# %%
df_limpio.sample(10)
# Out:
#      FechaInicio  NúmeroEntrevista  DISTRITO  (P0B*R1AE) - Sexo (anotar)  \
# 4385   07-oct-25           1454044         9                           1
# 6583   20-oct-25           1456242         2                           1
# 184    22-sep-25           1449843        12                           1
# 1917   30-sep-25           1451576         5                           2
# 5499   13-oct-25           1455158        21                           2
# 2903   02-oct-25           1452562        12                           2
# 2147   30-sep-25           1451806         8                           1
# 3836   04-oct-25           1453495        20                           2
# 63     20-sep-25           1449722         2                           2
# 8245   25-oct-25           1457904         3                           1
#
#       (P0D*R1AS) - ¿Me puede decir su edad?  \
# 4385                                      2
# 6583                                      3
# 184                                       1
# 1917                                      2
# 5499                                      5
# 2903                                      1
# 2147                                      5
# 3836                                      4
# 63                                        2
# 8245                                      5
#
#       P0F*R1AS) - Actualmente, ¿está viviendo en...?  \
# 4385                                               1
# 6583                                               4
# 184                                                3
# 1917                                               4
# 5499                                               1
# 2903                                               2
# 2147                                               1
# 3836                                               4
# 63                                                 2
# 8245                                               4
#
#       (P1*M1AS) - b - En su distrito  (P1*M1AS) - c - En su barrio  \
# 4385                               8                             9
# 6583                              10                            99
# 184                                7                             8
# 1917                               7                             7
# 5499                              10                            10
# 2903                               6                             5
# 2147                               8                             8
# 3836                              10                            10
# 63                                 9                             9
# 8245                              10                            10
#
#       (P2*M10S) - b - En su distrito  (P2*M10S) - c - En su barrio  \
# 4385                               7                             8
# 6583                               8                            10
# 184                                5                             6
# 1917                               6                             7
# 5499                               9                             9
# 2903                               6                             5
# 2147                               7                             7
# 3836                               8                             9
# 63                                 9                             9
# 8245                               9                             9
#
#       (P3*M10S) - a - En Madrid  (P3*M10S) - b - En su distrito  \
# 4385                          5                               5
# 6583                          7                               8
# 184                           3                               4
# 1917                          2                               3
# 5499                          8                               9
# 2903                          5                               5
# 2147                          5                               5
# 3836                          7                               8
# 63                            9                               9
# 8245                          6                               6
#
#       (P3*M10S) - c - En su barrio  \
# 4385                             5
# 6583                             8
# 184                              5
# 1917                             4
# 5499                            10
# 2903                             5
# 2147                             5
# 3836                             8
# 63                               9
# 8245                             6
#
#       (P4*M10S) - a - Cuidado y conservación de la ciudad  \
# 4385                                                  8
# 6583                                                  7
# 184                                                   6
# 1917                                                  6
# 5499                                                  6
# 2903                                                  9
# 2147                                                  4
# 3836                                                  9
# 63                                                    9
# 8245                                                  7
#
#       (P4*M10S) - b - Movilidad y transporte público  \
# 4385                                               7
# 6583                                               7
# 184                                                7
# 1917                                              10
# 5499                                               8
# 2903                                               9
# 2147                                               7
# 3836                                              10
# 63                                                 9
# 8245                                              10
#
#       (P4*M10S) - c - Calidad medioambiental  \
# 4385                                       4
# 6583                                       7
# 184                                        1
# 1917                                       5
# 5499                                       8
# 2903                                       8
# 2147                                       4
# 3836                                       5
# 63                                         8
# 8245                                       7
#
#       (P4*M10S) - d - Facilidad para encontrar un trabajo  \
# 4385                                                  8
# 6583                                                  8
# 184                                                   2
# 1917                                                  8
# 5499                                                  7
# 2903                                                  4
# 2147                                                  4
# 3836                                                  5
# 63                                                    8
# 8245                                                  9
#
#       (P4*M10S) - e - Facilidad para emprender un negocio  \
# 4385                                                  4
# 6583                                                  7
# 184                                                  99
# 1917                                                  1
# 5499                                                  5
# 2903                                                  8
# 2147                                                  4
# 3836                                                 99
# 63                                                    7
# 8245                                                 99
#
#       (P4*M10S) - f - Imagen internacional de Madrid  \
# 4385                                               7
# 6583                                               9
# 184                                                2
# 1917                                              10
# 5499                                               8
# 2903                                               5
# 2147                                               6
# 3836                                               9
# 63                                                 8
# 8245                                              10
#
#       (P4*M10S) - g - Coste de la vida  (P4*M10S) - h - Integración social  \
# 4385                                 9                                   8
# 6583                                10                                   9
# 184                                  2                                   1
# 1917                                 0                                   6
# 5499                                 7                                   7
# 2903                                 4                                   8
# 2147                                 3                                   5
# 3836                                 3                                   9
# 63                                   6                                   9
# 8245                                 3                                   8
#
#       (P4*M10S) - i - Salud y servicios sanitarios  \
# 4385                                             5
# 6583                                             8
# 184                                              3
# 1917                                             2
# 5499                                             9
# 2903                                             8
# 2147                                             4
# 3836                                             5
# 63                                               7
# 8245                                             7
#
#       (P4*M10S) - j - Educación y centros educativos  \
# 4385                                              99
# 6583                                               9
# 184                                                5
# 1917                                               9
# 5499                                              99
# 2903                                               7
# 2147                                               4
# 3836                                               8
# 63                                                 9
# 8245                                              10
#
#       (P4*M10S) - k - Facilidad para encontrar una vivienda en el marco de sus posibilidades  \
# 4385                                                  2
# 6583                                                  8
# 184                                                   0
# 1917                                                  1
# 5499                                                  5
# 2903                                                  3
# 2147                                                  2
# 3836                                                  0
# 63                                                    5
# 8245                                                  0
#
#       (P4*M10S) - l - Facilidad para hacer deporte  \
# 4385                                             8
# 6583                                            10
# 184                                              5
# 1917                                            10
# 5499                                             8
# 2903                                            10
# 2147                                             6
# 3836                                            10
# 63                                               9
# 8245                                            10
#
#       (P4*M10S) - m - Oferta cultural, ocio y diversión  \
# 4385                                                  7
# 6583                                                 10
# 184                                                   1
# 1917                                                 10
# 5499                                                  8
# 2903                                                  7
# 2147                                                  7
# 3836                                                  9
# 63                                                    9
# 8245                                                 10
#
#       (P4*M10S) - n - Convivencia vecinal  (P4*M10S) - o - Seguridad  \
# 4385                                    9                          7
# 6583                                    8                          7
# 184                                     3                          7
# 1917                                   99                          6
# 5499                                    7                          6
# 2903                                    6                          6
# 2147                                    5                          6
# 3836                                    9                          6
# 63                                      9                          9
# 8245                                    5                          8
#
#       (P5B*R1AE) - Anotar 2ª problema  \
# 4385                              NaN
# 6583                              NaN
# 184                               NaN
# 1917                              NaN
# 5499                              6.0
# 2903                              NaN
# 2147                              NaN
# 3836                              8.0
# 63                               99.0
# 8245                             10.0
#
#       (P6*M10S) - a - Desigualdad de oportunidades entre hombres y mujeres  \
# 4385                                                NaN
# 6583                                                NaN
# 184                                                 NaN
# 1917                                                NaN
# 5499                                                6.0
# 2903                                                NaN
# 2147                                                NaN
# 3836                                                7.0
# 63                                                  5.0
# 8245                                                2.0
#
#       (P6*M10S) - b - Desigualdad de oportunidades entre la población extranjera y autóctona  \
# 4385                                                NaN
# 6583                                                NaN
# 184                                                 NaN
# 1917                                                NaN
# 5499                                                6.0
# 2903                                                NaN
# 2147                                                NaN
# 3836                                                8.0
# 63                                                  6.0
# 8245                                                2.0
#
#       (P7*M10S) - a - Las personas mayores  (P7*M10S) - b - La infancia  \
# 4385                                   NaN                          NaN
# 6583                                   NaN                          NaN
# 184                                    NaN                          NaN
# 1917                                   NaN                          NaN
# 5499                                   9.0                          5.0
# 2903                                   NaN                          NaN
# 2147                                   NaN                          NaN
# 3836                                   7.0                          9.0
# 63                                     7.0                          6.0
# 8245                                   7.0                          7.0
#
#       (P7*M10S) - c - Las personas con discapacidad  \
# 4385                                            NaN
# 6583                                            NaN
# 184                                             NaN
# 1917                                            NaN
# 5499                                            8.0
# 2903                                            NaN
# 2147                                            NaN
# 3836                                            7.0
# 63                                              7.0
# 8245                                            7.0
#
#       (P7*M10S) - d - Las personas lgtbiq+  (P7*M10S) - e - Los migrantes  \
# 4385                                   NaN                            NaN
# 6583                                   NaN                            NaN
# 184                                    NaN                            NaN
# 1917                                   NaN                            NaN
# 5499                                   8.0                            8.0
# 2903                                   NaN                            NaN
# 2147                                   NaN                            NaN
# 3836                                   9.0                            8.0
# 63                                     6.0                            6.0
# 8245                                   6.0                            6.0
#
#       (7*M10S) - f - La adolescencia  \
# 4385                             NaN
# 6583                             NaN
# 184                              NaN
# 1917                             NaN
# 5499                            99.0
# 2903                             NaN
# 2147                             NaN
# 3836                             9.0
# 63                               7.0
# 8245                             3.0
#
#       (P8*M10S) - a - La recogida de basuras y contenedores  \
# 4385                                                NaN
# 6583                                                NaN
# 184                                                 NaN
# 1917                                                NaN
# 5499                                                7.0
# 2903                                                NaN
# 2147                                                NaN
# 3836                                                9.0
# 63                                                  8.0
# 8245                                                8.0
#
#       (P8*M10S) - b - La gestión y tratamiento de residuos (reciclaje, compostaje, etc.)  \
# 4385                                                NaN
# 6583                                                NaN
# 184                                                 NaN
# 1917                                                NaN
# 5499                                                8.0
# 2903                                                NaN
# 2147                                                NaN
# 3836                                                8.0
# 63                                                  7.0
# 8245                                                8.0
#
#       (P8*M10S) - c - El control de la contaminación atmosférica  \
# 4385                                                NaN
# 6583                                                NaN
# 184                                                 NaN
# 1917                                                NaN
# 5499                                                7.0
# 2903                                                NaN
# 2147                                                NaN
# 3836                                                8.0
# 63                                                  9.0
# 8245                                                8.0
#
#       (P8*M10S) - d - El control del ruido  \
# 4385                                   NaN
# 6583                                   NaN
# 184                                    NaN
# 1917                                   NaN
# 5499                                   7.0
# 2903                                   NaN
# 2147                                   NaN
# 3836                                   8.0
# 63                                     9.0
# 8245                                   5.0
#
#       (P8*M10S) - e - La limpieza de las calles  \
# 4385                                        NaN
# 6583                                        NaN
# 184                                         NaN
# 1917                                        NaN
# 5499                                        9.0
# 2903                                        NaN
# 2147                                        NaN
# 3836                                        9.0
# 63                                          8.0
# 8245                                        6.0
#
#       (P8*M10S) - f - El alumbrado público  \
# 4385                                   NaN
# 6583                                   NaN
# 184                                    NaN
# 1917                                   NaN
# 5499                                   7.0
# 2903                                   NaN
# 2147                                   NaN
# 3836                                   9.0
# 63                                     8.0
# 8245                                   8.0
#
#       (P8*M10S) - g - Las infraestructuras de la ciudad para la circulación de vehículos (calles, túneles, etc.…)  \
# 4385                                                NaN
# 6583                                                NaN
# 184                                                 NaN
# 1917                                                NaN
# 5499                                                8.0
# 2903                                                NaN
# 2147                                                NaN
# 3836                                                8.0
# 63                                                  7.0
# 8245                                               10.0
#
#       (P8*M10S) - h - La pavimentación y conservación de las aceras  \
# 4385                                                NaN
# 6583                                                NaN
# 184                                                 NaN
# 1917                                                NaN
# 5499                                                6.0
# 2903                                                NaN
# 2147                                                NaN
# 3836                                                8.0
# 63                                                  9.0
# 8245                                                6.0
#
#       (P8*M10S) - i - El asfaltado y conservación de las calzadas  \
# 4385                                                NaN
# 6583                                                NaN
# 184                                                 NaN
# 1917                                                NaN
# 5499                                                7.0
# 2903                                                NaN
# 2147                                                NaN
# 3836                                                8.0
# 63                                                  8.0
# 8245                                                7.0
#
#       (P8*M10S) - j - La peatonalización de calles  \
# 4385                                           NaN
# 6583                                           NaN
# 184                                            NaN
# 1917                                           NaN
# 5499                                           7.0
# 2903                                           NaN
# 2147                                           NaN
# 3836                                           8.0
# 63                                             8.0
# 8245                                           8.0
#
#       (P8*M10S) - k - La eliminación de barreras arquitectónicas (rebaje de bordillos, semáforos acústicos, etc.)  \
# 4385                                                NaN
# 6583                                                NaN
# 184                                                 NaN
# 1917                                                NaN
# 5499                                                6.0
# 2903                                                NaN
# 2147                                                NaN
# 3836                                                6.0
# 63                                                  8.0
# 8245                                                3.0
#
#       (P8*M10S) - l - La movilidad sostenible  \
# 4385                                      NaN
# 6583                                      NaN
# 184                                       NaN
# 1917                                      NaN
# 5499                                      6.0
# 2903                                      NaN
# 2147                                      NaN
# 3836                                      8.0
# 63                                        8.0
# 8245                                     99.0
#
#       (P8*M10S) - v - La mejora de la calidad del aire  \
# 4385                                               NaN
# 6583                                               NaN
# 184                                                NaN
# 1917                                               NaN
# 5499                                               7.0
# 2903                                               NaN
# 2147                                               NaN
# 3836                                               7.0
# 63                                                 7.0
# 8245                                              99.0
#
#       (P8*M10S) - m - La conservación y rehabilitación de los edificios  \
# 4385                                                NaN
# 6583                                                NaN
# 184                                                 NaN
# 1917                                                NaN
# 5499                                                7.0
# 2903                                                NaN
# 2147                                                NaN
# 3836                                                6.0
# 63                                                  7.0
# 8245                                               99.0
#
#       (P8*M10S) - n - La protección de monumentos y del patrimonio histórico-artístico  \
# 4385                                                NaN
# 6583                                                NaN
# 184                                                 NaN
# 1917                                                NaN
# 5499                                                8.0
# 2903                                                NaN
# 2147                                                NaN
# 3836                                                8.0
# 63                                                  9.0
# 8245                                               10.0
#
#       (P8*M10S) - o - La información y promoción turística  \
# 4385                                                NaN
# 6583                                                NaN
# 184                                                 NaN
# 1917                                                NaN
# 5499                                                7.0
# 2903                                                NaN
# 2147                                                NaN
# 3836                                                9.0
# 63                                                  6.0
# 8245                                                8.0
#
#       (P8*M10S) - p - La organización de fiestas y eventos populares (cabalgata, fiestas de san isidro, fiestas de los distritos...)  \
# 4385                                                NaN
# 6583                                                NaN
# 184                                                 NaN
# 1917                                                NaN
# 5499                                                8.0
# 2903                                                NaN
# 2147                                                NaN
# 3836                                                9.0
# 63                                                  7.0
# 8245                                                9.0
#
#       (P8*M10S) - q - El control de la salud pública (plagas, alimentos, aguas...)  \
# 4385                                                NaN
# 6583                                                NaN
# 184                                                 NaN
# 1917                                                NaN
# 5499                                                8.0
# 2903                                                NaN
# 2147                                                NaN
# 3836                                                9.0
# 63                                                  8.0
# 8245                                                8.0
#
#       (P8*M10S) - r - Las ayudas e incentivos a pymes y autónomos  \
# 4385                                                NaN
# 6583                                                NaN
# 184                                                 NaN
# 1917                                                NaN
# 5499                                                6.0
# 2903                                                NaN
# 2147                                                NaN
# 3836                                               99.0
# 63                                                  7.0
# 8245                                               99.0
#
#       (P8*M10S) - t - La promoción pública de viviendas  \
# 4385                                                NaN
# 6583                                                NaN
# 184                                                 NaN
# 1917                                                NaN
# 5499                                                7.0
# 2903                                                NaN
# 2147                                                NaN
# 3836                                                7.0
# 63                                                  7.0
# 8245                                                0.0
#
#       (P8*M10S) - w - La actuación frente a la ocupación ilegal  \
# 4385                                                NaN
# 6583                                                NaN
# 184                                                 NaN
# 1917                                                NaN
# 5499                                                4.0
# 2903                                                NaN
# 2147                                                NaN
# 3836                                                0.0
# 63                                                  8.0
# 8245                                                0.0
#
#       (P8*M10S) - u - Los beneficios fiscales promovidos por el ayuntamiento (bajada de impuestos, bonificaciones...)  \
# 4385                                                NaN
# 6583                                                NaN
# 184                                                 NaN
# 1917                                                NaN
# 5499                                                8.0
# 2903                                                NaN
# 2147                                                NaN
# 3836                                                7.0
# 63                                                  8.0
# 8245                                                1.0
#
#       (P8*M10S) - x - El plan de fomento de la natalidad y la conciliación (el cheque bebé)  \
# 4385                                                NaN
# 6583                                                NaN
# 184                                                 NaN
# 1917                                                NaN
# 5499                                                7.0
# 2903                                                NaN
# 2147                                                NaN
# 3836                                                6.0
# 63                                                  9.0
# 8245                                                2.0
#
#       (P9*M10S) - a - La atención a la ciudadanía  \
# 4385                                          7.0
# 6583                                          8.0
# 184                                           6.0
# 1917                                          8.0
# 5499                                          NaN
# 2903                                          4.0
# 2147                                          5.0
# 3836                                          NaN
# 63                                            NaN
# 8245                                          NaN
#
#       (P9*M10S) - c - El servicio de autobuses de la Emt  \
# 4385                                                7.0
# 6583                                                8.0
# 184                                                 6.0
# 1917                                               10.0
# 5499                                                NaN
# 2903                                                7.0
# 2147                                                7.0
# 3836                                                NaN
# 63                                                  NaN
# 8245                                                NaN
#
#       (P9*M10S) - d - Los taxis  \
# 4385                        9.0
# 6583                        7.0
# 184                         0.0
# 1917                       10.0
# 5499                        NaN
# 2903                        8.0
# 2147                        5.0
# 3836                        NaN
# 63                          NaN
# 8245                        NaN
#
#       (P9*M10S) - e - El ser (servicio de estacionamiento regulado)  \
# 4385                                                6.0
# 6583                                               99.0
# 184                                                 3.0
# 1917                                                8.0
# 5499                                                NaN
# 2903                                                4.0
# 2147                                                5.0
# 3836                                                NaN
# 63                                                  NaN
# 8245                                                NaN
#
#       (P9*M10S) - f - Los agentes de movilidad  \
# 4385                                      99.0
# 6583                                      99.0
# 184                                        5.0
# 1917                                       8.0
# 5499                                       NaN
# 2903                                       8.0
# 2147                                       8.0
# 3836                                       NaN
# 63                                         NaN
# 8245                                       NaN
#
#       (P9*M10S) - g - La policía municipal  (P9*M10S) - h - Los bomberos  \
# 4385                                   7.0                          99.0
# 6583                                   8.0                           9.0
# 184                                    0.0                          10.0
# 1917                                  10.0                          10.0
# 5499                                   NaN                           NaN
# 2903                                   8.0                          10.0
# 2147                                   7.0                           9.0
# 3836                                   NaN                           NaN
# 63                                     NaN                           NaN
# 8245                                   NaN                           NaN
#
#       (P9*M10S) - i - Samur – protección civil  \
# 4385                                      99.0
# 6583                                       9.0
# 184                                        8.0
# 1917                                      10.0
# 5499                                       NaN
# 2903                                       8.0
# 2147                                       6.0
# 3836                                       NaN
# 63                                         NaN
# 8245                                       NaN
#
#       (P9*M10S) - j - La beca infantil para la escolarización 0-3 años  \
# 4385                                               99.0
# 6583                                                9.0
# 184                                                99.0
# 1917                                                6.0
# 5499                                                NaN
# 2903                                                6.0
# 2147                                               99.0
# 3836                                                NaN
# 63                                                  NaN
# 8245                                                NaN
#
#       (P9*M10S) - k - Los servicios sociales municipales (mayores, personas con discapacidad, inmigrantes, familias, …)  \
# 4385                                               99.0
# 6583                                               99.0
# 184                                                 0.0
# 1917                                                9.0
# 5499                                                NaN
# 2903                                                7.0
# 2147                                                5.0
# 3836                                                NaN
# 63                                                  NaN
# 8245                                                NaN
#
#       (P9*M10S) - l - Las vías ciclistas  \
# 4385                                 0.0
# 6583                                 7.0
# 184                                  5.0
# 1917                                99.0
# 5499                                 NaN
# 2903                                10.0
# 2147                                 5.0
# 3836                                 NaN
# 63                                   NaN
# 8245                                 NaN
#
#       (P9*M10S) - m - Los aparcamientos municipales  \
# 4385                                           99.0
# 6583                                            7.0
# 184                                             0.0
# 1917                                            9.0
# 5499                                            NaN
# 2903                                            8.0
# 2147                                            5.0
# 3836                                            NaN
# 63                                              NaN
# 8245                                            NaN
#
#       (P9*M10S) - n - Los puntos limpios de recogida y reciclaje de residuos  \
# 4385                                                5.0
# 6583                                                7.0
# 184                                                 1.0
# 1917                                               10.0
# 5499                                                NaN
# 2903                                                8.0
# 2147                                                8.0
# 3836                                                NaN
# 63                                                  NaN
# 8245                                                NaN
#
#       (P9*M10S) - o - Los espacios verdes (parques y jardines)  \
# 4385                                                7.0
# 6583                                                8.0
# 184                                                 6.0
# 1917                                                8.0
# 5499                                                NaN
# 2903                                               10.0
# 2147                                                4.0
# 3836                                                NaN
# 63                                                  NaN
# 8245                                                NaN
#
#       (P9*M10S) - p - Los parques infantiles  \
# 4385                                    99.0
# 6583                                     8.0
# 184                                      5.0
# 1917                                     5.0
# 5499                                     NaN
# 2903                                     7.0
# 2147                                    99.0
# 3836                                     NaN
# 63                                       NaN
# 8245                                     NaN
#
#       (P9*M10S) - q - Los mercados municipales  \
# 4385                                       5.0
# 6583                                       7.0
# ...
# 63                                                  NaN
# 8245                                                NaN
#
#       (P15*M10S) - f - Chat on line de línea Madrid  \
# 4385                                            4.0
# 6583                                           99.0
# 184                                             0.0
# 1917                                           99.0
# 5499                                            NaN
# 2903                                            6.0
# 2147                                            7.0
# 3836                                            NaN
# 63                                              NaN
# 8245                                            NaN
#
#       (P15*M10S) - g - Atención directa a las personas mayores, con número preferente y atención presencial sin cita previa  \
# 4385                                               99.0
# 6583                                               99.0
# 184                                                99.0
# 1917                                                9.0
# 5499                                                NaN
# 2903                                                9.0
# 2147                                               99.0
# 3836                                                NaN
# 63                                                  NaN
# 8245                                                NaN
#
#       (P16*M10S) - a - Administración general del estado  \
# 4385                                                NaN
# 6583                                                NaN
# 184                                                 NaN
# 1917                                                NaN
# 5499                                                5.0
# 2903                                                NaN
# 2147                                                NaN
# 3836                                                1.0
# 63                                                  8.0
# 8245                                                2.0
#
#       (P16*M10S) - b - Administración de la comunidad de Madrid  \
# 4385                                                NaN
# 6583                                                NaN
# 184                                                 NaN
# 1917                                                NaN
# 5499                                                6.0
# 2903                                                NaN
# 2147                                                NaN
# 3836                                                9.0
# 63                                                  8.0
# 8245                                                8.0
#
#       (P16*M10S) - c - Administración del ayuntamiento de Madrid  \
# 4385                                                NaN
# 6583                                                NaN
# 184                                                 NaN
# 1917                                                NaN
# 5499                                                7.0
# 2903                                                NaN
# 2147                                                NaN
# 3836                                                9.0
# 63                                                  8.0
# 8245                                                7.0
#
#       (P17*R10S) - ¿Y en términos generales, en una escala de 0 a 10 ¿cómo calificaría usted la gestión que está realizando el equipo de gobierno del ayuntamiento de Madrid?  \
# 4385                                                NaN
# 6583                                                NaN
# 184                                                 NaN
# 1917                                                NaN
# 5499                                                8.0
# 2903                                                NaN
# 2147                                                NaN
# 3836                                                9.0
# 63                                                  9.0
# 8245                                                7.0
#
#       (P18*R10S) - En una escala de 0 a 10, ¿cómo está de satisfecho/a con la administración del ayuntamiento de Madrid?  \
# 4385                                                NaN
# 6583                                                NaN
# 184                                                 NaN
# 1917                                                NaN
# 5499                                                9.0
# 2903                                                NaN
# 2147                                                NaN
# 3836                                               10.0
# 63                                                 10.0
# 8245                                                7.0
#
#       (P19*R10S) - Poniendo en relación los impuestos que paga al ayuntamiento y los servicios que recibe. En una escala de 0 a 10 ¿cómo de satisfecho/a está?  \
# 4385                                                1.0
# 6583                                                8.0
# 184                                                 3.0
# 1917                                                1.0
# 5499                                                NaN
# 2903                                                4.0
# 2147                                                3.0
# 3836                                                NaN
# 63                                                  NaN
# 8245                                                NaN
#
#       (P20*M2AS) - a - Primero  (P20*M2AS) - b - Segundo  \
# 4385                       2.0                      11.0
# 6583                      11.0                       2.0
# 184                        6.0                      11.0
# 1917                       4.0                       8.0
# 5499                       NaN                       NaN
# 2903                       6.0                      11.0
# 2147                       6.0                       5.0
# 3836                       NaN                       NaN
# 63                         NaN                       NaN
# 8245                       NaN                       NaN
#
#       (P21*R1AS) - Y para terminar, a efectos de analísis estadístico, voy a hacerle algunas preguntas. ¿Podría indicarme su nacionalidad?  \
# 4385                                                  1
# 6583                                                  1
# 184                                                   1
# 1917                                                  1
# 5499                                                  1
# 2903                                                  1
# 2147                                                  1
# 3836                                                  1
# 63                                                    1
# 8245                                                  1
#
#       (P22*R1AE) - ¿Cuáles son los estudios de más alto nivel oficial que usted ha cursado (con independencia de que los haya terminado o no)?  \
# 4385                                                  6
# 6583                                                  6
# 184                                                   5
# 1917                                                  6
# 5499                                                  5
# 2903                                                  4
# 2147                                                  5
# 3836                                                  5
# 63                                                    6
# 8245                                                  6
#
#       (P23*R1AS) - ¿En cuál de las siguientes situaciones se encuentra usted actualmente? situación principal.  \
# 4385                                                  1
# 6583                                                  1
# 184                                                   1
# 1917                                                  1
# 5499                                                  2
# 2903                                                  6
# 2147                                                  1
# 3836                                                  4
# 63                                                    1
# 8245                                                  2
#
#       (P24*R1AE) - ¿Y podría decirme a qué partido o coalición votó en las elecciones municipales de mayo de 2023?  \
# 4385                                                  1
# 6583                                                  8
# 184                                                  10
# 1917                                                  8
# 5499                                                  9
# 2903                                                 11
# 2147                                                  3
# 3836                                                  1
# 63                                                    1
# 8245                                                  1
#
#      Ponderacion
# 4385    0,780617
# 6583    0,725553
# 184     1,484672
# 1917    0,970158
# 5499    0,252885
# 2903    1,170663
# 2147    1,736503
# 3836    0,950179
# 63      0,882988
# 8245    0,691864

# %%
print(df_limpio.columns.tolist())
# Out:
# ['FechaInicio', 'NúmeroEntrevista', 'DISTRITO', '(P0B*R1AE) - Sexo (anotar)', '(P0D*R1AS) - ¿Me puede decir su edad?', 'P0F*R1AS) - Actualmente, ¿está viviendo en...?', '(P1*M1AS) - b - En su distrito', '(P1*M1AS) - c - En su barrio', '(P2*M10S) - b - En su distrito', '(P2*M10S) - c - En su barrio', '(P3*M10S) - a - En Madrid', '(P3*M10S) - b - En su distrito', '(P3*M10S) - c - En su barrio', '(P4*M10S) - a - Cuidado y conservación de la ciudad', '(P4*M10S) - b - Movilidad y transporte público', '(P4*M10S) - c - Calidad medioambiental', '(P4*M10S) - d - Facilidad para encontrar un trabajo', '(P4*M10S) - e - Facilidad para emprender un negocio', '(P4*M10S) - f - Imagen internacional de Madrid', '(P4*M10S) - g - Coste de la vida', '(P4*M10S) - h - Integración social', '(P4*M10S) - i - Salud y servicios sanitarios', '(P4*M10S) - j - Educación y centros educativos', '(P4*M10S) - k - Facilidad para encontrar una vivienda en el marco de sus posibilidades', '(P4*M10S) - l - Facilidad para hacer deporte', '(P4*M10S) - m - Oferta cultural, ocio y diversión', '(P4*M10S) - n - Convivencia vecinal', '(P4*M10S) - o - Seguridad', '(P5B*R1AE) - Anotar 2ª problema', '(P6*M10S) - a - Desigualdad de oportunidades entre hombres y mujeres', '(P6*M10S) - b - Desigualdad de oportunidades entre la población extranjera y autóctona', '(P7*M10S) - a - Las personas mayores', '(P7*M10S) - b - La infancia', '(P7*M10S) - c - Las personas con discapacidad', '(P7*M10S) - d - Las personas lgtbiq+', '(P7*M10S) - e - Los migrantes', '(7*M10S) - f - La adolescencia', '(P8*M10S) - a - La recogida de basuras y contenedores', '(P8*M10S) - b - La gestión y tratamiento de residuos (reciclaje, compostaje, etc.)', '(P8*M10S) - c - El control de la contaminación atmosférica', '(P8*M10S) - d - El control del ruido', '(P8*M10S) - e - La limpieza de las calles', '(P8*M10S) - f - El alumbrado público', '(P8*M10S) - g - Las infraestructuras de la ciudad para la circulación de vehículos (calles, túneles, etc.…)', '(P8*M10S) - h - La pavimentación y conservación de las aceras', '(P8*M10S) - i - El asfaltado y conservación de las calzadas', '(P8*M10S) - j - La peatonalización de calles', '(P8*M10S) - k - La eliminación de barreras arquitectónicas (rebaje de bordillos, semáforos acústicos, etc.)', '(P8*M10S) - l - La movilidad sostenible', '(P8*M10S) - v - La mejora de la calidad del aire', '(P8*M10S) - m - La conservación y rehabilitación de los edificios', '(P8*M10S) - n - La protección de monumentos y del patrimonio histórico-artístico', '(P8*M10S) - o - La información y promoción turística', '(P8*M10S) - p - La organización de fiestas y eventos populares (cabalgata, fiestas de san isidro, fiestas de los distritos...)', '(P8*M10S) - q - El control de la salud pública (plagas, alimentos, aguas...)', '(P8*M10S) - r - Las ayudas e incentivos a pymes y autónomos', '(P8*M10S) - t - La promoción pública de viviendas', '(P8*M10S) - w - La actuación frente a la ocupación ilegal', '(P8*M10S) - u - Los beneficios fiscales promovidos por el ayuntamiento (bajada de impuestos, bonificaciones...)', '(P8*M10S) - x - El plan de fomento de la natalidad y la conciliación (el cheque bebé)', '(P9*M10S) - a - La atención a la ciudadanía', '(P9*M10S) - c - El servicio de autobuses de la Emt', '(P9*M10S) - d - Los taxis', '(P9*M10S) - e - El ser (servicio de estacionamiento regulado)', '(P9*M10S) - f - Los agentes de movilidad', '(P9*M10S) - g - La policía municipal', '(P9*M10S) - h - Los bomberos', '(P9*M10S) - i - Samur – protección civil', '(P9*M10S) - j - La beca infantil para la escolarización 0-3 años', '(P9*M10S) - k - Los servicios sociales municipales (mayores, personas con discapacidad, inmigrantes, familias, …)', '(P9*M10S) - l - Las vías ciclistas', '(P9*M10S) - m - Los aparcamientos municipales', '(P9*M10S) - n - Los puntos limpios de recogida y reciclaje de residuos', '(P9*M10S) - o - Los espacios verdes (parques y jardines)', '(P9*M10S) - p - Los parques infantiles', '(P9*M10S) - q - ...

# %%
df_limpio.info
# Out:
# <bound method DataFrame.info of      FechaInicio  NúmeroEntrevista  DISTRITO  (P0B*R1AE) - Sexo (anotar)  \
# 0      19-sep-25           1449659         2                           1
# 1      19-sep-25           1449660         4                           1
# 2      19-sep-25           1449661         8                           1
# 3      19-sep-25           1449662         5                           1
# 4      19-sep-25           1449663        20                           1
# ...          ...               ...       ...                         ...
# 8588   30-oct-25           1458247        21                           1
# 8589   30-oct-25           1458248        21                           2
# 8590   30-oct-25           1458249         9                           2
# 8591   30-oct-25           1458250         9                           2
# 8592   30-oct-25           1458251         9                           1
#
#       (P0D*R1AS) - ¿Me puede decir su edad?  \
# 0                                         1
# 1                                         4
# 2                                         3
# 3                                         3
# 4                                         4
# ...                                     ...
# 8588                                      1
# 8589                                      2
# 8590                                      2
# 8591                                      2
# 8592                                      2
#
#       P0F*R1AS) - Actualmente, ¿está viviendo en...?  \
# 0                                                  1
# 1                                                  1
# 2                                                  4
# 3                                                  4
# 4                                                  3
# ...                                              ...
# 8588                                               3
# 8589                                               5
# 8590                                               3
# 8591                                               4
# 8592                                               3
#
#       (P1*M1AS) - b - En su distrito  (P1*M1AS) - c - En su barrio  \
# 0                                  9                             9
# 1                                  9                            10
# 2                                  8                             9
# 3                                  7                             8
# 4                                  7                            10
# ...                              ...                           ...
# 8588                              10                            10
# 8589                               6                             6
# 8590                               4                             2
# 8591                               8                             8
# 8592                              10                            10
#
#       (P2*M10S) - b - En su distrito  (P2*M10S) - c - En su barrio  \
# 0                                  8                             9
# 1                                  9                             9
# 2                                  7                             8
# 3                                  7                             7
# 4                                  7                             9
# ...                              ...                           ...
# 8588                               8                             8
# 8589                               6                             6
# 8590                               6                             2
# 8591                               9                             8
# 8592                              10                            10
#
#       (P3*M10S) - a - En Madrid  (P3*M10S) - b - En su distrito  \
# 0                             8                               9
# 1                            10                              10
# 2                             7                               8
# 3                             6                               9
# 4                            10                               9
# ...                         ...                             ...
# 8588                          4                               6
# 8589                          4                               6
# 8590                          4                               2
# 8591                          8                               8
# 8592                          8                              10
#
#       (P3*M10S) - c - En su barrio  \
# 0                               10
# 1                               10
# 2                                9
# 3                                8
# 4                               10
# ...                            ...
# 8588                             6
# 8589                             6
# 8590                             0
# 8591                             8
# 8592                            10
#
#       (P4*M10S) - a - Cuidado y conservación de la ciudad  \
# 0                                                     8
# 1                                                     8
# 2                                                     5
# 3                                                     7
# 4                                                     8
# ...                                                 ...
# 8588                                                  6
# 8589                                                  5
# 8590                                                  8
# 8591                                                  6
# 8592                                                  9
#
#       (P4*M10S) - b - Movilidad y transporte público  \
# 0                                                 10
# 1                                                 10
# 2                                                  7
# 3                                                  8
# 4                                                  9
# ...                                              ...
# 8588                                               8
# 8589                                               7
# 8590                                              10
# 8591                                               8
# 8592                                               8
#
#       (P4*M10S) - c - Calidad medioambiental  \
# 0                                          9
# 1                                          7
# 2                                          5
# 3                                          6
# 4                                          6
# ...                                      ...
# 8588                                       8
# 8589                                       7
# 8590                                       7
# 8591                                       5
# 8592                                       6
#
#       (P4*M10S) - d - Facilidad para encontrar un trabajo  \
# 0                                                     8
# 1                                                     9
# 2                                                     5
# 3                                                     7
# 4                                                     7
# ...                                                 ...
# 8588                                                  9
# 8589                                                  4
# 8590                                                  8
# 8591                                                  8
# 8592                                                 10
#
#       (P4*M10S) - e - Facilidad para emprender un negocio  \
# 0                                                    99
# 1                                                     9
# 2                                                     5
# 3                                                     6
# 4                                                     7
# ...                                                 ...
# 8588                                                 99
# 8589                                                  5
# 8590                                                  5
# 8591                                                  3
# 8592                                                 10
#
#       (P4*M10S) - f - Imagen internacional de Madrid  \
# 0                                                  9
# 1                                                 10
# 2                                                  8
# 3                                                  8
# 4                                                  9
# ...                                              ...
# 8588                                              10
# 8589                                               9
# 8590                                               9
# 8591                                               8
# 8592                                              10
#
#       (P4*M10S) - g - Coste de la vida  (P4*M10S) - h - Integración social  \
# 0                                    5                                   8
# 1                                    7                                   8
# 2                                    5                                   7
# 3                                    9                                   7
# 4                                    5                                  99
# ...                                ...                                 ...
# 8588                                 4                                   7
# 8589                                 0                                   3
# 8590                                 0                                   7
# 8591                                 5                                   8
# 8592                                 7                                   9
#
#       (P4*M10S) - i - Salud y servicios sanitarios  \
# 0                                                8
# 1                                                8
# 2                                                5
# 3                                                7
# 4                                                9
# ...                                            ...
# 8588                                             8
# 8589                                             5
# 8590                                             4
# 8591                                             8
# 8592                                             9
#
#       (P4*M10S) - j - Educación y centros educativos  \
# 0                                                  8
# 1                                                  8
# 2                                                  7
# 3                                                  7
# 4                                                 99
# ...                                              ...
# 8588                                              99
# 8589                                               3
# 8590                                               7
# 8591                                               8
# 8592                                               8
#
#       (P4*M10S) - k - Facilidad para encontrar una vivienda en el marco de sus posibilidades  \
# 0                                                     4
# 1                                                     7
# 2                                                     2
# 3                                                     7
# 4                                                     4
# ...                                                 ...
# 8588                                                  3
# 8589                                                  1
# 8590                                                  2
# 8591                                                  4
# 8592                                                  0
#
#       (P4*M10S) - l - Facilidad para hacer deporte  \
# 0                                               10
# 1                                                9
# 2                                                7
# 3                                                7
# 4                                               10
# ...                                            ...
# 8588                                            10
# 8589                                             6
# 8590                                             9
# 8591                                             8
# 8592                                            10
#
#       (P4*M10S) - m - Oferta cultural, ocio y diversión  \
# 0                                                    10
# 1                                                    10
# 2                                                     8
# 3                                                     7
# 4                                                    10
# ...                                                 ...
# 8588                                                 10
# 8589                                                 10
# 8590                                                 10
# 8591                                                  8
# 8592                                                 10
#
#       (P4*M10S) - n - Convivencia vecinal  (P4*M10S) - o - Seguridad  \
# 0                                       7                          9
# 1                                       7                          8
# 2                                       7                          7
# 3                                       7                          7
# 4                                       8                          7
# ...                                   ...                        ...
# 8588                                    6                          7
# 8589                                    4                          5
# 8590                                    8                          8
# 8591                                    5                          5
# 8592                                   10                         10
#
#       (P5B*R1AE) - Anotar 2ª problema  \
# 0                                97.0
# 1                                 NaN
# 2                                 8.0
# 3                                 NaN
# 4                                 NaN
# ...                               ...
# 8588                              NaN
# 8589                              NaN
# 8590                              8.0
# 8591                              9.0
# 8592                              1.0
#
#       (P6*M10S) - a - Desigualdad de oportunidades entre hombres y mujeres  \
# 0                                                   7.0
# 1                                                   NaN
# 2                                                   7.0
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 8588                                                NaN
# 8589                                                NaN
# 8590                                                2.0
# 8591                                                5.0
# 8592                                                0.0
#
#       (P6*M10S) - b - Desigualdad de oportunidades entre la población extranjera y autóctona  \
# 0                                                   7.0
# 1                                                   NaN
# 2                                                   7.0
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 8588                                                NaN
# 8589                                                NaN
# 8590                                                6.0
# 8591                                                5.0
# 8592                                                3.0
#
#       (P7*M10S) - a - Las personas mayores  (P7*M10S) - b - La infancia  \
# 0                                      8.0                          8.0
# 1                                      NaN                          NaN
# 2                                      5.0                          5.0
# 3                                      NaN                          NaN
# 4                                      NaN                          NaN
# ...                                    ...                          ...
# 8588                                   NaN                          NaN
# 8589                                   NaN                          NaN
# 8590                                   8.0                          6.0
# 8591                                   8.0                          8.0
# 8592                                   7.0                         10.0
#
#       (P7*M10S) - c - Las personas con discapacidad  \
# 0                                               7.0
# 1                                               NaN
# 2                                               5.0
# 3                                               NaN
# 4                                               NaN
# ...                                             ...
# 8588                                            NaN
# 8589                                            NaN
# 8590                                            7.0
# 8591                                            8.0
# 8592                                           10.0
#
#       (P7*M10S) - d - Las personas lgtbiq+  (P7*M10S) - e - Los migrantes  \
# 0                                      8.0                            7.0
# 1                                      NaN                            NaN
# 2                                      7.0                            5.0
# 3                                      NaN                            NaN
# 4                                      NaN                            NaN
# ...                                    ...                            ...
# 8588                                   NaN                            NaN
# 8589                                   NaN                            NaN
# 8590                                   7.0                            7.0
# 8591                                   8.0                            5.0
# 8592                                  10.0                           10.0
#
#       (7*M10S) - f - La adolescencia  \
# 0                                8.0
# 1                                NaN
# 2                                8.0
# 3                                NaN
# 4                                NaN
# ...                              ...
# 8588                             NaN
# 8589                             NaN
# 8590                             6.0
# 8591                             8.0
# 8592                            10.0
#
#       (P8*M10S) - a - La recogida de basuras y contenedores  \
# 0                                                   8.0
# 1                                                   NaN
# 2                                                   6.0
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 8588                                                NaN
# 8589                                                NaN
# 8590                                                5.0
# 8591                                                8.0
# 8592                                                8.0
#
#       (P8*M10S) - b - La gestión y tratamiento de residuos (reciclaje, compostaje, etc.)  \
# 0                                                   8.0
# 1                                                   NaN
# 2                                                   5.0
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 8588                                                NaN
# 8589                                                NaN
# 8590                                                2.0
# 8591                                                5.0
# 8592                                                7.0
#
#       (P8*M10S) - c - El control de la contaminación atmosférica  \
# 0                                                   7.0
# 1                                                   NaN
# 2                                                   5.0
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 8588                                                NaN
# 8589                                                NaN
# 8590                                                7.0
# 8591                                                3.0
# 8592                                                5.0
#
#       (P8*M10S) - d - El control del ruido  \
# 0                                      8.0
# 1                                      NaN
# 2                                      5.0
# 3                                      NaN
# 4                                      NaN
# ...                                    ...
# 8588                                   NaN
# 8589                                   NaN
# 8590                                   3.0
# 8591                                   3.0
# 8592                                   7.0
#
#       (P8*M10S) - e - La limpieza de las calles  \
# 0                                           8.0
# 1                                           NaN
# 2                                           5.0
# 3                                           NaN
# 4                                           NaN
# ...                                         ...
# 8588                                        NaN
# 8589                                        NaN
# 8590                                        9.0
# 8591                                        3.0
# 8592                                        7.0
#
#       (P8*M10S) - f - El alumbrado público  \
# 0                                      8.0
# 1                                      NaN
# 2                                      5.0
# 3                                      NaN
# 4                                      NaN
# ...                                    ...
# 8588                                   NaN
# 8589                                   NaN
# 8590                                   8.0
# 8591                                   6.0
# 8592                                   9.0
#
#       (P8*M10S) - g - Las infraestructuras de la ciudad para la circulación de vehículos (calles, túneles, etc.…)  \
# 0                                                   9.0
# 1                                                   NaN
# 2                                                   6.0
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 8588                                                NaN
# 8589                                                NaN
# 8590                                                8.0
# 8591                                                5.0
# 8592                                                8.0
#
#       (P8*M10S) - h - La pavimentación y conservación de las aceras  \
# 0                                                   7.0
# 1                                                   NaN
# 2                                                   2.0
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 8588                                                NaN
# 8589                                                NaN
# 8590                                                7.0
# 8591                                                4.0
# 8592                                                6.0
#
#       (P8*M10S) - i - El asfaltado y conservación de las calzadas  \
# 0                                                   8.0
# 1                                                   NaN
# 2                                                   2.0
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 8588                                                NaN
# 8589                                                NaN
# 8590                                                9.0
# 8591                                                5.0
# 8592                                                8.0
#
#       (P8*M10S) - j - La peatonalización de calles  \
# 0                                              8.0
# 1                                              NaN
# 2                                              5.0
# 3                                              NaN
# 4                                              NaN
# ...                                            ...
# 8588                                           NaN
# 8589                                           NaN
# 8590                                           7.0
# 8591                                           6.0
# 8592                                           7.0
#
#       (P8*M10S) - k - La eliminación de barreras arquitectónicas (rebaje de bordillos, semáforos acústicos, etc.)  \
# 0                                                   7.0
# 1                                                   NaN
# 2                                                   5.0
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 8588                                                NaN
# 8589                                                NaN
# 8590                                                7.0
# 8591                                                2.0
# 8592                                                8.0
#
#       (P8*M10S) - l - La movilidad sostenible  \
# 0                                         8.0
# 1                                         NaN
# 2                                         5.0
# 3                                         NaN
# 4                                         NaN
# ...                                       ...
# 8588                                      NaN
# 8589                                      NaN
# 8590                                      7.0
# 8591                                      6.0
# 8592                                      8.0
#
#       (P8*M10S) - v - La mejora de la calidad del aire  \
# 0                                                  7.0
# 1                                                  NaN
# 2                                                  5.0
# 3                                                  NaN
# 4                                                  NaN
# ...                                                ...
# 8588                                               NaN
# 8589                                               NaN
# 8590                                               7.0
# 8591                                               1.0
# 8592                                               7.0
#
#       (P8*M10S) - m - La conservación y rehabilitación de los edificios  \
# 0                                                   7.0
# 1                                                   NaN
# 2                                                   5.0
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 8588                                                NaN
# 8589                                                NaN
# 8590                                                3.0
# 8591                                                4.0
# 8592                                                9.0
#
#       (P8*M10S) - n - La protección de monumentos y del patrimonio histórico-artístico  \
# 0                                                   8.0
# 1                                                   NaN
# 2                                                   7.0
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 8588                                                NaN
# 8589                                                NaN
# 8590                                                8.0
# 8591                                                7.0
# 8592                                                7.0
#
#       (P8*M10S) - o - La información y promoción turística  \
# 0                                                   8.0
# 1                                                   NaN
# 2                                                   8.0
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 8588                                                NaN
# 8589                                                NaN
# 8590                                                8.0
# 8591                                                8.0
# 8592                                               99.0
#
#       (P8*M10S) - p - La organización de fiestas y eventos populares (cabalgata, fiestas de san isidro, fiestas de los distritos...)  \
# 0                                                   7.0
# 1                                                   NaN
# 2                                                   7.0
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 8588                                                NaN
# 8589                                                NaN
# 8590                                                7.0
# 8591                                                8.0
# 8592                                                9.0
#
#       (P8*M10S) - q - El control de la salud pública (plagas, alimentos, aguas...)  \
# 0                                                   7.0
# 1                                                   NaN
# 2                                                   5.0
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 8588                                                NaN
# 8589                                                NaN
# 8590                                                5.0
# 8591                                                6.0
# 8592                                                9.0
#
#       (P8*M10S) - r - Las ayudas e incentivos a pymes y autónomos  \
# 0                                                   9.0
# 1                                                   NaN
# 2                                                   6.0
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 8588                                                NaN
# 8589                                                NaN
# 8590                                                4.0
# 8591                                                2.0
# 8592                                               99.0
#
#       (P8*M10S) - t - La promoción pública de viviendas  \
# 0                                                   5.0
# 1                                                   NaN
# 2                                                   2.0
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 8588                                                NaN
# 8589                                                NaN
# 8590                                                8.0
# 8591                                                2.0
# 8592                                                5.0
#
#       (P8*M10S) - w - La actuación frente a la ocupación ilegal  \
# 0                                                   8.0
# 1                                                   NaN
# 2                                                   2.0
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 8588                                                NaN
# 8589                                                NaN
# 8590                                                2.0
# 8591                                                0.0
# 8592                                                8.0
#
#       (P8*M10S) - u - Los beneficios fiscales promovidos por el ayuntamiento (bajada de impuestos, bonificaciones...)  \
# 0                                                   8.0
# 1                                                   NaN
# 2                                                   8.0
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 8588                                                NaN
# 8589                                                NaN
# 8590                                                4.0
# 8591                                                1.0
# 8592                                               10.0
#
#       (P8*M10S) - x - El plan de fomento de la natalidad y la conciliación (el cheque bebé)  \
# 0                                                   6.0
# 1                                                   NaN
# 2                                                   5.0
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 8588                                                NaN
# 8589                                                NaN
# 8590                                                5.0
# 8591                                                6.0
# 8592                                               99.0
#
#       (P9*M10S) - a - La atención a la ciudadanía  \
# 0                                             NaN
# 1                                             8.0
# 2                                             NaN
# 3                                             7.0
# 4                                             8.0
# ...                                           ...
# 8588                                         99.0
# 8589                                          6.0
# 8590                                          NaN
# 8591                                          NaN
# 8592                                          NaN
#
#       (P9*M10S) - c - El servicio de autobuses de la Emt  \
# 0                                                   NaN
# 1                                                  10.0
# 2                                                   NaN
# 3                                                   7.0
# 4                                                   9.0
# ...                                                 ...
# 8588                                                8.0
# 8589                                                7.0
# 8590                                                NaN
# 8591                                                NaN
# 8592                                                NaN
#
#       (P9*M10S) - d - Los taxis  \
# 0                           NaN
# 1                           8.0
# 2                           NaN
# 3                           6.0
# 4                           6.0
# ...                         ...
# 8588                        8.0
# 8589                        6.0
# 8590                        NaN
# 8591                        NaN
# 8592                        NaN
#
#       (P9*M10S) - e - El ser (servicio de estacionamiento regulado)  \
# 0                                                   NaN
# 1                                                   9.0
# 2                                                   NaN
# 3                                                   8.0
# 4                                                   6.0
# ...                                                 ...
# 8588                                               99.0
# 8589                                                1.0
# 8590                                                NaN
# 8591                                                NaN
# 8592                                                NaN
#
#       (P9*M10S) - f - Los agentes de movilidad  \
# 0                                          NaN
# 1                                          8.0
# 2                                          NaN
# 3                                          7.0
# 4                                          6.0
# ...                                        ...
# 8588                                      99.0
# 8589                                       7.0
# 8590                                       NaN
# 8591                                       NaN
# 8592                                       NaN
#
#       (P9*M10S) - g - La policía municipal  (P9*M10S) - h - Los bomberos  \
# 0                                      NaN                           NaN
# 1                                      8.0                          10.0
# 2                                      NaN                           NaN
# 3                                      8.0                           7.0
# 4                                      8.0                          10.0
# ...                                    ...                           ...
# 8588                                   7.0                          99.0
# 8589                                   7.0                           8.0
# 8590                                   NaN                           NaN
# 8591                                   NaN                           NaN
# 8592                                   NaN                           NaN
#
#       (P9*M10S) - i - Samur – protección civil  \
# 0                                          NaN
# 1                                          9.0
# 2                                          NaN
# 3                                          6.0
# 4                                         10.0
# ...                                        ...
# 8588                                      99.0
# 8589                                       8.0
# 8590                                       NaN
# 8591                                       NaN
# 8592                                       NaN
#
#       (P9*M10S) - j - La beca infantil para la escolarización 0-3 años  \
# 0                                                   NaN
# 1                                                   9.0
# 2                                                   NaN
# 3                                                   8.0
# 4                                                  99.0
# ...                                                 ...
# 8588                                               99.0
# 8589                                                9.0
# 8590                                                NaN
# 8591                                                NaN
# 8592                                                NaN
#
#       (P9*M10S) - k - Los servicios sociales municipales (mayores, personas con discapacidad, inmigrantes, familias, …)  \
# 0                                                   NaN
# 1                                                   8.0
# 2                                                   NaN
# 3                                                   8.0
# 4                                                   8.0
# ...
# ...                                                 ...
# 8588                                               99.0
# 8589                                               10.0
# 8590                                                NaN
# 8591                                                NaN
# 8592                                                NaN
#
#       (P16*M10S) - a - Administración general del estado  \
# 0                                                   9.0
# 1                                                   NaN
# 2                                                   2.0
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 8588                                                NaN
# 8589                                                NaN
# 8590                                                4.0
# 8591                                               99.0
# 8592                                                7.0
#
#       (P16*M10S) - b - Administración de la comunidad de Madrid  \
# 0                                                   8.0
# 1                                                   NaN
# 2                                                   5.0
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 8588                                                NaN
# 8589                                                NaN
# 8590                                                9.0
# 8591                                               99.0
# 8592                                                9.0
#
#       (P16*M10S) - c - Administración del ayuntamiento de Madrid  \
# 0                                                   8.0
# 1                                                   NaN
# 2                                                   4.0
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 8588                                                NaN
# 8589                                                NaN
# 8590                                                8.0
# 8591                                               99.0
# 8592                                                9.0
#
#       (P17*R10S) - ¿Y en términos generales, en una escala de 0 a 10 ¿cómo calificaría usted la gestión que está realizando el equipo de gobierno del ayuntamiento de Madrid?  \
# 0                                                   6.0
# 1                                                   NaN
# 2                                                   6.0
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 8588                                                NaN
# 8589                                                NaN
# 8590                                                9.0
# 8591                                                4.0
# 8592                                                9.0
#
#       (P18*R10S) - En una escala de 0 a 10, ¿cómo está de satisfecho/a con la administración del ayuntamiento de Madrid?  \
# 0                                                   5.0
# 1                                                   NaN
# 2                                                   6.0
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 8588                                                NaN
# 8589                                                NaN
# 8590                                                8.0
# 8591                                                4.0
# 8592                                                9.0
#
#       (P19*R10S) - Poniendo en relación los impuestos que paga al ayuntamiento y los servicios que recibe. En una escala de 0 a 10 ¿cómo de satisfecho/a está?  \
# 0                                                   NaN
# 1                                                   9.0
# 2                                                   NaN
# 3                                                   8.0
# 4                                                   8.0
# ...                                                 ...
# 8588                                                4.0
# 8589                                                5.0
# 8590                                                NaN
# 8591                                                NaN
# 8592                                                NaN
#
#       (P20*M2AS) - a - Primero  (P20*M2AS) - b - Segundo  \
# 0                          NaN                       NaN
# 1                          7.0                       6.0
# 2                          NaN                       NaN
# 3                          1.0                       6.0
# 4                          6.0                       1.0
# ...                        ...                       ...
# 8588                       5.0                       1.0
# 8589                       5.0                       7.0
# 8590                       NaN                       NaN
# 8591                       NaN                       NaN
# 8592                       NaN                       NaN
#
#       (P21*R1AS) - Y para terminar, a efectos de analísis estadístico, voy a hacerle algunas preguntas. ¿Podría indicarme su nacionalidad?  \
# 0                                                     1
# 1                                                     1
# 2                                                     1
# 3                                                     1
# 4                                                     1
# ...                                                 ...
# 8588                                                  1
# 8589                                                  1
# 8590                                                  1
# 8591                                                  1
# 8592                                                  1
#
#       (P22*R1AE) - ¿Cuáles son los estudios de más alto nivel oficial que usted ha cursado (con independencia de que los haya terminado o no)?  \
# 0                                                     6
# 1                                                     6
# 2                                                     6
# 3                                                     5
# 4                                                     5
# ...                                                 ...
# 8588                                                  5
# 8589                                                  6
# 8590                                                  5
# 8591                                                  5
# 8592                                                  6
#
#       (P23*R1AS) - ¿En cuál de las siguientes situaciones se encuentra usted actualmente? situación principal.  \
# 0                                                     1
# 1                                                     1
# 2                                                     1
# 3                                                     1
# 4                                                     4
# ...                                                 ...
# 8588                                                  1
# 8589                                                  1
# 8590                                                  1
# 8591                                                  1
# 8592                                                  1
#
#       (P24*R1AE) - ¿Y podría decirme a qué partido o coalición votó en las elecciones municipales de mayo de 2023?  \
# 0                                                    10
# 1                                                     1
# 2                                                     7
# 3                                                     5
# 4                                                     1
# ...                                                 ...
# 8588                                                  1
# 8589                                                 97
# 8590                                                 10
# 8591                                                  1
# 8592                                                  1
#
#      Ponderacion
# 0       1,236126
# 1       0,787242
# 2       1,270241
# 3       0,692541
# 4       1,023298
# ...          ...
# 8588    0,564545
# 8589    0,272866
# 8590    0,788612
# 8591    0,788612
# 8592    0,780617
#
# [8593 rows x 110 columns]>

# %%
lista_eliminar_2 = ['(P11*M10S) - a - Y en general', '(P12*M10S) - b - Durante el día', '(P12*M10S) - c - Durante la noche', '(P14*R10S) - Trataremos a continuación de la administración y el gobierno del ayuntamiento de Madrid  en la misma escala, ¿en qué medida se considera usted  informado/a  de lo que hace el ayuntamiento de Madrid?', '(P15*M10S) - a - Las oficinas de atención a la ciudadanía de línea Madrid', '(P15*M10S) - b - El teléfono 010', '(P15*M10S) - c - La web del ayuntamiento de Madrid: www.madrid.es', '(P15*M10S) - d - Aplicaciones del ayuntamiento para dispositivos móviles (app para móviles, Madrid móvil, emt Madrid…)', '(P15*M10S) - e - Las oficinas de atención al contribuyente', '(P15*M10S) - f - Chat on line de línea Madrid', '(P15*M10S) - g - Atención directa a las personas mayores, con número preferente y atención presencial sin cita previa', '(P16*M10S) - a - Administración general del estado', '(P16*M10S) - b - Administración de la comunidad de Madrid', '(P16*M10S) - c - Administración del ayuntamiento de Madrid', '(P17*R10S) - ¿Y en términos generales, en una escala de 0 a 10 ¿cómo calificaría usted la gestión que está realizando el equipo de gobierno del ayuntamiento de Madrid?', '(P18*R10S) - En una escala de 0 a 10, ¿cómo está de satisfecho/a con la administración del ayuntamiento de Madrid?', '(P19*R10S) - Poniendo en relación los impuestos que paga al ayuntamiento y los servicios que recibe. En una escala de 0 a 10 ¿cómo de satisfecho/a está?', '(P20*M2AS) - a - Primero', ' (P20*M2AS) - b - Segundo', '(P21*R1AS) - Y para terminar, a efectos de analísis estadístico, voy a hacerle algunas preguntas. ¿Podría indicarme su nacionalidad?', '(P22*R1AE) - ¿Cuáles son los estudios de más alto nivel oficial que usted ha cursado (con independencia de que los haya terminado o no)?', '(P23*R1AS) - ¿En cuál de las siguientes situaciones se encuentra usted actualmente? situación principal.', '(P24*R1AE) - ¿Y podría decirme a qué partido o coalición votó en las elecciones municipales de mayo de 2023?', 'Columna:  Ponderacion']

# %%
df_limpio2 = df_limpio.drop(columns=lista_eliminar_2, errors='ignore')

# %%
df_limpio2.shape
# Out:
# (8593, 88)

# %%
df_limpio2.head()
# Out:
#   FechaInicio  NúmeroEntrevista  DISTRITO  (P0B*R1AE) - Sexo (anotar)  \
# 0   19-sep-25           1449659         2                           1
# 1   19-sep-25           1449660         4                           1
# 2   19-sep-25           1449661         8                           1
# 3   19-sep-25           1449662         5                           1
# 4   19-sep-25           1449663        20                           1
#
#    (P0D*R1AS) - ¿Me puede decir su edad?  \
# 0                                      1
# 1                                      4
# 2                                      3
# 3                                      3
# 4                                      4
#
#    P0F*R1AS) - Actualmente, ¿está viviendo en...?  \
# 0                                               1
# 1                                               1
# 2                                               4
# 3                                               4
# 4                                               3
#
#    (P1*M1AS) - b - En su distrito  (P1*M1AS) - c - En su barrio  \
# 0                               9                             9
# 1                               9                            10
# 2                               8                             9
# 3                               7                             8
# 4                               7                            10
#
#    (P2*M10S) - b - En su distrito  (P2*M10S) - c - En su barrio  \
# 0                               8                             9
# 1                               9                             9
# 2                               7                             8
# 3                               7                             7
# 4                               7                             9
#
#    (P3*M10S) - a - En Madrid  (P3*M10S) - b - En su distrito  \
# 0                          8                               9
# 1                         10                              10
# 2                          7                               8
# 3                          6                               9
# 4                         10                               9
#
#    (P3*M10S) - c - En su barrio  \
# 0                            10
# 1                            10
# 2                             9
# 3                             8
# 4                            10
#
#    (P4*M10S) - a - Cuidado y conservación de la ciudad  \
# 0                                                  8
# 1                                                  8
# 2                                                  5
# 3                                                  7
# 4                                                  8
#
#    (P4*M10S) - b - Movilidad y transporte público  \
# 0                                              10
# 1                                              10
# 2                                               7
# 3                                               8
# 4                                               9
#
#    (P4*M10S) - c - Calidad medioambiental  \
# 0                                       9
# 1                                       7
# 2                                       5
# 3                                       6
# 4                                       6
#
#    (P4*M10S) - d - Facilidad para encontrar un trabajo  \
# 0                                                  8
# 1                                                  9
# 2                                                  5
# 3                                                  7
# 4                                                  7
#
#    (P4*M10S) - e - Facilidad para emprender un negocio  \
# 0                                                 99
# 1                                                  9
# 2                                                  5
# 3                                                  6
# 4                                                  7
#
#    (P4*M10S) - f - Imagen internacional de Madrid  \
# 0                                               9
# 1                                              10
# 2                                               8
# 3                                               8
# 4                                               9
#
#    (P4*M10S) - g - Coste de la vida  (P4*M10S) - h - Integración social  \
# 0                                 5                                   8
# 1                                 7                                   8
# 2                                 5                                   7
# 3                                 9                                   7
# 4                                 5                                  99
#
#    (P4*M10S) - i - Salud y servicios sanitarios  \
# 0                                             8
# 1                                             8
# 2                                             5
# 3                                             7
# 4                                             9
#
#    (P4*M10S) - j - Educación y centros educativos  \
# 0                                               8
# 1                                               8
# 2                                               7
# 3                                               7
# 4                                              99
#
#    (P4*M10S) - k - Facilidad para encontrar una vivienda en el marco de sus posibilidades  \
# 0                                                  4
# 1                                                  7
# 2                                                  2
# 3                                                  7
# 4                                                  4
#
#    (P4*M10S) - l - Facilidad para hacer deporte  \
# 0                                            10
# 1                                             9
# 2                                             7
# 3                                             7
# 4                                            10
#
#    (P4*M10S) - m - Oferta cultural, ocio y diversión  \
# 0                                                 10
# 1                                                 10
# 2                                                  8
# 3                                                  7
# 4                                                 10
#
#    (P4*M10S) - n - Convivencia vecinal  (P4*M10S) - o - Seguridad  \
# 0                                    7                          9
# 1                                    7                          8
# 2                                    7                          7
# 3                                    7                          7
# 4                                    8                          7
#
#    (P5B*R1AE) - Anotar 2ª problema  \
# 0                             97.0
# 1                              NaN
# 2                              8.0
# 3                              NaN
# 4                              NaN
#
#    (P6*M10S) - a - Desigualdad de oportunidades entre hombres y mujeres  \
# 0                                                7.0
# 1                                                NaN
# 2                                                7.0
# 3                                                NaN
# 4                                                NaN
#
#    (P6*M10S) - b - Desigualdad de oportunidades entre la población extranjera y autóctona  \
# 0                                                7.0
# 1                                                NaN
# 2                                                7.0
# 3                                                NaN
# 4                                                NaN
#
#    (P7*M10S) - a - Las personas mayores  (P7*M10S) - b - La infancia  \
# 0                                   8.0                          8.0
# 1                                   NaN                          NaN
# 2                                   5.0                          5.0
# 3                                   NaN                          NaN
# 4                                   NaN                          NaN
#
#    (P7*M10S) - c - Las personas con discapacidad  \
# 0                                            7.0
# 1                                            NaN
# 2                                            5.0
# 3                                            NaN
# 4                                            NaN
#
#    (P7*M10S) - d - Las personas lgtbiq+  (P7*M10S) - e - Los migrantes  \
# 0                                   8.0                            7.0
# 1                                   NaN                            NaN
# 2                                   7.0                            5.0
# 3                                   NaN                            NaN
# 4                                   NaN                            NaN
#
#    (7*M10S) - f - La adolescencia  \
# 0                             8.0
# 1                             NaN
# 2                             8.0
# 3                             NaN
# 4                             NaN
#
#    (P8*M10S) - a - La recogida de basuras y contenedores  \
# 0                                                8.0
# 1                                                NaN
# 2                                                6.0
# 3                                                NaN
# 4                                                NaN
#
#    (P8*M10S) - b - La gestión y tratamiento de residuos (reciclaje, compostaje, etc.)  \
# 0                                                8.0
# 1                                                NaN
# 2                                                5.0
# 3                                                NaN
# 4                                                NaN
#
#    (P8*M10S) - c - El control de la contaminación atmosférica  \
# 0                                                7.0
# 1                                                NaN
# 2                                                5.0
# 3                                                NaN
# 4                                                NaN
#
#    (P8*M10S) - d - El control del ruido  \
# 0                                   8.0
# 1                                   NaN
# 2                                   5.0
# 3                                   NaN
# 4                                   NaN
#
#    (P8*M10S) - e - La limpieza de las calles  \
# 0                                        8.0
# 1                                        NaN
# 2                                        5.0
# 3                                        NaN
# 4                                        NaN
#
#    (P8*M10S) - f - El alumbrado público  \
# 0                                   8.0
# 1                                   NaN
# 2                                   5.0
# 3                                   NaN
# 4                                   NaN
#
#    (P8*M10S) - g - Las infraestructuras de la ciudad para la circulación de vehículos (calles, túneles, etc.…)  \
# 0                                                9.0
# 1                                                NaN
# 2                                                6.0
# 3                                                NaN
# 4                                                NaN
#
#    (P8*M10S) - h - La pavimentación y conservación de las aceras  \
# 0                                                7.0
# 1                                                NaN
# 2                                                2.0
# 3                                                NaN
# 4                                                NaN
#
#    (P8*M10S) - i - El asfaltado y conservación de las calzadas  \
# 0                                                8.0
# 1                                                NaN
# 2                                                2.0
# 3                                                NaN
# 4                                                NaN
#
#    (P8*M10S) - j - La peatonalización de calles  \
# 0                                           8.0
# 1                                           NaN
# 2                                           5.0
# 3                                           NaN
# 4                                           NaN
#
#    (P8*M10S) - k - La eliminación de barreras arquitectónicas (rebaje de bordillos, semáforos acústicos, etc.)  \
# 0                                                7.0
# 1                                                NaN
# 2                                                5.0
# 3                                                NaN
# 4                                                NaN
#
#    (P8*M10S) - l - La movilidad sostenible  \
# 0                                      8.0
# 1                                      NaN
# 2                                      5.0
# 3                                      NaN
# 4                                      NaN
#
#    (P8*M10S) - v - La mejora de la calidad del aire  \
# 0                                               7.0
# 1                                               NaN
# 2                                               5.0
# 3                                               NaN
# 4                                               NaN
#
#    (P8*M10S) - m - La conservación y rehabilitación de los edificios  \
# 0                                                7.0
# 1                                                NaN
# 2                                                5.0
# 3                                                NaN
# 4                                                NaN
#
#    (P8*M10S) - n - La protección de monumentos y del patrimonio histórico-artístico  \
# 0                                                8.0
# 1                                                NaN
# 2                                                7.0
# 3                                                NaN
# 4                                                NaN
#
#    (P8*M10S) - o - La información y promoción turística  \
# 0                                                8.0
# 1                                                NaN
# 2                                                8.0
# 3                                                NaN
# 4                                                NaN
#
#    (P8*M10S) - p - La organización de fiestas y eventos populares (cabalgata, fiestas de san isidro, fiestas de los distritos...)  \
# 0                                                7.0
# 1                                                NaN
# 2                                                7.0
# 3                                                NaN
# 4                                                NaN
#
#    (P8*M10S) - q - El control de la salud pública (plagas, alimentos, aguas...)  \
# 0                                                7.0
# 1                                                NaN
# 2                                                5.0
# 3                                                NaN
# 4                                                NaN
#
#    (P8*M10S) - r - Las ayudas e incentivos a pymes y autónomos  \
# 0                                                9.0
# 1                                                NaN
# 2                                                6.0
# 3                                                NaN
# 4                                                NaN
#
#    (P8*M10S) - t - La promoción pública de viviendas  \
# 0                                                5.0
# 1                                                NaN
# 2                                                2.0
# 3                                                NaN
# 4                                                NaN
#
#    (P8*M10S) - w - La actuación frente a la ocupación ilegal  \
# 0                                                8.0
# 1                                                NaN
# 2                                                2.0
# 3                                                NaN
# 4                                                NaN
#
#    (P8*M10S) - u - Los beneficios fiscales promovidos por el ayuntamiento (bajada de impuestos, bonificaciones...)  \
# 0                                                8.0
# 1                                                NaN
# 2                                                8.0
# 3                                                NaN
# 4                                                NaN
#
#    (P8*M10S) - x - El plan de fomento de la natalidad y la conciliación (el cheque bebé)  \
# 0                                                6.0
# 1                                                NaN
# 2                                                5.0
# 3                                                NaN
# 4                                                NaN
#
#    (P9*M10S) - a - La atención a la ciudadanía  \
# 0                                          NaN
# 1                                          8.0
# 2                                          NaN
# 3                                          7.0
# 4                                          8.0
#
#    (P9*M10S) - c - El servicio de autobuses de la Emt  \
# 0                                                NaN
# 1                                               10.0
# 2                                                NaN
# 3                                                7.0
# 4                                                9.0
#
#    (P9*M10S) - d - Los taxis  \
# 0                        NaN
# 1                        8.0
# 2                        NaN
# 3                        6.0
# 4                        6.0
#
#    (P9*M10S) - e - El ser (servicio de estacionamiento regulado)  \
# 0                                                NaN
# 1                                                9.0
# 2                                                NaN
# 3                                                8.0
# 4                                                6.0
#
#    (P9*M10S) - f - Los agentes de movilidad  \
# 0                                       NaN
# 1                                       8.0
# 2                                       NaN
# 3                                       7.0
# 4                                       6.0
#
#    (P9*M10S) - g - La policía municipal  (P9*M10S) - h - Los bomberos  \
# 0                                   NaN                           NaN
# 1                                   8.0                          10.0
# 2                                   NaN                           NaN
# 3                                   8.0                           7.0
# 4                                   8.0                          10.0
#
#    (P9*M10S) - i - Samur – protección civil  \
# 0                                       NaN
# 1                                       9.0
# 2                                       NaN
# 3                                       6.0
# 4                                      10.0
#
#    (P9*M10S) - j - La beca infantil para la escolarización 0-3 años  \
# 0                                                NaN
# 1                                                9.0
# 2                                                NaN
# 3                                                8.0
# 4                                               99.0
#
#    (P9*M10S) - k - Los servicios sociales municipales (mayores, personas con discapacidad, inmigrantes, familias, …)  \
# 0                                                NaN
# 1                                                8.0
# 2                                                NaN
# 3                                                8.0
# 4                                                8.0
#
#    (P9*M10S) - l - Las vías ciclistas  \
# 0                                 NaN
# 1                                 7.0
# 2                                 NaN
# 3                                 7.0
# 4                                 5.0
#
#    (P9*M10S) - m - Los aparcamientos municipales  \
# 0                                            NaN
# 1                                            9.0
# 2                                            NaN
# 3                                            8.0
# 4                                            8.0
#
#    (P9*M10S) - n - Los puntos limpios de recogida y reciclaje de residuos  \
# 0                                                NaN
# 1                                                9.0
# 2                                                NaN
# 3                                                5.0
# 4                                                9.0
#
#    (P9*M10S) - o - Los espacios verdes (parques y jardines)  \
# 0                                                NaN
# 1                                                8.0
# 2                                                NaN
# 3                                                7.0
# 4                                                9.0
#
#    (P9*M10S) - p - Los parques infantiles  \
# 0                                     NaN
# 1                                     8.0
# 2                                     NaN
# 3                                     7.0
# 4                                     8.0
#
#    (P9*M10S) - q - Los mercados municipales  \
# 0                                       NaN
# 1                                       8.0
# 2                                       NaN
# 3                                       8.0
# 4                                       9.0
#
#    (P9*M10S) - r - Las instalaciones deportivas municipales  \
# 0                                                NaN
# 1                                                8.0
# 2                                                NaN
# 3                                                6.0
# 4                                               10.0
#
#    (P9*M10S) - s - Los centros culturales municipales  \
# 0                                                NaN
# 1                                                8.0
# 2                                                NaN
# 3                                                7.0
# 4                                               10.0
#
#    (P9*M10S) - t - Las bibliotecas municipales  \
# 0                                          NaN
# 1                                          8.0
# 2                                          NaN
# 3                                          8.0
# 4                                         10.0
#
#    (P9*M10S) - u - Los teatros municipales (Español, Matadero, Fernán Gómez…)  \
# 0                                                NaN
# 1                                                8.0
# 2                                                NaN
# 3                                                9.0
# 4                                                9.0
#
#    (P9*M10S) - v - El Samur social  (P9*M10S) - w - Bicimad  \
# 0                              NaN                      NaN
# 1                              9.0                     99.0
# 2                              NaN                      NaN
# 3                              7.0                      5.0
# 4                              9.0                      5.0
#
#    (P11*M10S) - b - Durante el día  (P11*M10S) - c - Durante la noche  \
# 0                              NaN                                NaN
# 1                              9.0                                7.0
# 2                              NaN                                NaN
# 3                              8.0                                7.0
# 4                              9.0                                7.0
#
#    (P13*M10S) - b - Durante el día  (P13*M10S) - c - Durante la noche  \
# 0                              NaN                                NaN
# 1                              9.0                                9.0
# 2                              NaN                                NaN
# 3                              7.0                                8.0
# 4                             10.0                               10.0
#
#    (P20*M2AS) - b - Segundo Ponderacion
# 0                       NaN    1,236126
# 1                       6.0    0,787242
# 2                       NaN    1,270241
# 3                       6.0    0,692541
# 4                       1.0    1,023298

# %%
df_limpio2.to_csv('csv_calidaddevida.csv', index=False)
